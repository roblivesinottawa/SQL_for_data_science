# %%
import psycopg2
from sqlalchemy import create_engine
import pandas as pd

# %%
def get_engine(user, password, host, port, database):
    """
    Returns an engine to the database
    """
    return create_engine('postgresql://{}:{}@{}:{}/{}'.format(user, password, host, port, database))

engine = get_engine('rob_the_programmer', input("enter password: "), 'localhost', 5432, 'data_sci')
print(engine)
# Out:
# Engine(postgresql://rob_the_programmer:***@localhost:5432/data_sci)

# %%
query = "select * from employees;"
df_employees = pd.read_sql_query(query, engine)
df_employees.head()
# Out:
#      id  last_name                        email  start_date  salary  \
# 0     1     kelley      rkelley0@soundcloud.com  2015-09-19   67470
# 1    22  alexander  kalexanderl@marketwatch.com  2021-10-20  144724
# 2  1003       carr         fcarr2@woothemes.com  2018-09-20  101768
# 3    45     nguyen   mnguyen18@biblegateway.com  2021-06-21  108378
# 4    50  armstrong       parmstrong1d@hc360.com  2017-09-13   89969
#
#              job_title  region_id  department_id
# 0  structural engineer          2              6
# 1  marketing assistant          2              1
# 2   recruiting manager          3              1
# 3  electrical engineer          7              1
# 4        senior editor          4              1

# %%
df_employees[df_employees['salary'] > 100000]
# Out:
#         id  last_name                         email  start_date  salary  \
# 1       22  alexander   kalexanderl@marketwatch.com  2021-10-20  144724
# 2     1003       carr          fcarr2@woothemes.com  2018-09-20  101768
# 3       45     nguyen    mnguyen18@biblegateway.com  2021-06-21  108378
# 8       92      ortiz            aortiz2j@jigsy.com  2020-07-17  113231
# 9      103       reed       dreed2u@arstechnica.com  2016-12-19  126001
# ...    ...        ...                           ...         ...     ...
# 1038   804     hunter    hhuntermb@reverbnation.com  2023-07-03  123156
# 1042   874    spencer     kspencero9@eventbrite.com  2023-04-27  119769
# 1043   901      perry            kperryp0@chron.com  2021-10-06  146701
# 1044   935     hudson      mhudsonpy@altervista.org  2015-03-30  146745
# 1045   993   anderson  sandersonrk@businesswire.com  2023-11-26  139486
#
#                     job_title  region_id  department_id
# 1         marketing assistant          2              1
# 2          recruiting manager          3              1
# 3         electrical engineer          7              1
# 8               senior editor          7              1
# 9         structural engineer          6              1
# ...                       ...        ...            ...
# 1038            social worker          1             22
# 1042        director of sales          2             22
# 1043    research assistant ii          7             22
# 1044  assistant media planner          1             22
# 1045         product engineer          7             22
#
# [503 rows x 8 columns]

# %%
df_employees.isna().sum()
# Out:
# id               0
# last_name        0
# email            0
# start_date       0
# salary           0
# job_title        0
# region_id        0
# department_id    0
# dtype: int64

# %%
len(df_employees)
# Out:
# 1046

# %%
# find the minimum salary
df_employees['salary'].min()
# Out:
# 40138

# %%
# find the maximum salary
df_employees['salary'].max()
# Out:
# 149929

# %%
df_employees.last_name.unique()
# Out:
# array(['kelley', 'alexander', 'carr', 'nguyen', 'armstrong', 'ross',
#        'boyd', 'jordan', 'ortiz', 'reed', 'fox', 'lawson', 'morris',
#        'schmidt', 'torres', 'edwards', 'gutierrez', 'jenkins', 'hall',
#        'nichols', 'carroll', 'anderson', 'hawkins', 'sanchez', 'george',
#        'duncan', 'marshall', 'mcdonald', 'foster', 'morales', 'rose',
#        'simmons', 'gordon', 'meyer', 'thomas', 'burns', 'butler',
#        'wright', 'gonzales', 'owens', 'webb', 'peterson', 'adams',
#        'medina', 'kennedy', 'allen', 'dixon', 'vasquez', 'wallace',
#        'moore', 'wagner', 'barnes', 'day', 'sanders', 'tucker', 'ward',
#        'price', 'lewis', 'hudson', 'jones', 'sims', 'scott', 'howard',
#        'richards', 'morgan', 'bell', 'harrison', 'fowler', 'murphy',
#        'howell', 'miller', 'williams', 'bowman', 'bailey', 'weaver',
#        'rodriguez', 'coleman', 'mason', 'hayes', 'powell', 'rivera',
#        'andrews', 'stephens', 'ramos', 'peters', 'washington', 'brown',
#        'gomez', 'graham', 'lynch', 'ford', 'harvey', 'long', 'white',
#        'hansen', 'woods', 'hunt', 'jackson', 'carpenter', 'mendoza',
#        'crawford', 'reid', 'fisher', 'watkins', 'wilson', 'moreno',
#        'chapman', 'collins', 'ryan', 'cole', 'black', 'oliver',
#        'cunningham', 'perkins', 'freeman', 'ferguson', 'watson',
#        'richardson', 'berry', 'arnold', 'young', 'gray', 'williamson',
#        'kim', 'james', 'taylor', 'greene', 'phillips', 'roberts', 'hill',
#        'murray', 'elliott', 'olson', 'knight', 'rice', 'burton',
#        'johnson', 'castillo', 'austin', 'gibson', 'grant', 'wheeler',
#        'robertson', 'west', 'stevens', 'hanson', 'holmes', 'lee',
#        'gonzalez', 'little', 'evans', 'banks', 'walker', 'reyes',
#        'gardner', 'burke', 'stewart', 'lane', 'reynolds', 'montgomery',
#        'russell', 'martinez', 'ellis', 'robinson', 'garrett', 'lawrence',
#        'hamilton', 'ramirez', 'gilbert', 'stone', 'jacobs', 'garza',
#        'king', 'stanley', 'spencer', 'cooper', 'turner', 'baker', 'smith',
#        'griffin', 'parker', 'matthews', 'snyder', 'hernandez', 'henry',
#        'cox', 'kelly', 'mills', 'franklin', 'chavez', 'shaw', 'bennett',
#        'clark', 'hunter', 'carter', 'lopez', 'ruiz', 'cook', 'willis',
#        'perry', 'daniels', 'myers', 'nelson', 'pierce', 'frazier',
#        'garcia', 'payne', 'diaz', 'cruz', 'sullivan', 'fuller', 'brooks',
#        'johnston', 'hicks', 'porter', 'campbell', 'harper', 'welch',
#        'bryant', 'wells', 'dunn', 'mccoy', 'hart', 'bishop', 'flores',
#        'riley', 'wood', 'hughes', 'martin', 'dean', 'thompson', 'harris',
#        'warren', 'perez', 'fields', 'bradley', 'larson', 'palmer',
#        'alvarez', 'henderson', 'romero', 'simpson', 'ray', 'morrison'],
#       dtype=object)

# %%
len(df_employees.last_name.unique())
# Out:
# 244

# %%
query = "select * from company_regions;"
df_company_regions = pd.read_sql_query(query, engine)
print(df_company_regions)
# Out:
#    id       region_name country_name
# 0   1         northeast          usa
# 1   2         southeast          usa
# 2   3         northwest          usa
# 3   4         southwest          usa
# 4   5  british columbia       canada
# 5   6            quebec       canada
# 6   7       nova scotia       canada

# %%
query = "select * from company_departments;"
df_company_departments = pd.read_sql_query(query, engine)
print(df_company_departments)
# Out:
#     id department_name         division_name
# 0    1      automotive       auto & hardware
# 1    2            baby              domestic
# 2    3          beauty              domestic
# 3    4        clothing              domestic
# 4    5       computers  electronic equipment
# 5    6     electronics  electronic equipment
# 6    7           games              domestic
# 7    8          garden     outdoors & garden
# 8    9         grocery              domestic
# 9   10          health              domestic
# 10  11            home              domestic
# 11  12      industrial       auto & hardware
# 12  13        jewelery               fashion
# 13  14            kids              domestic
# 14  15          movies         entertainment
# 15  16           music         entertainment
# 16  17        outdoors     outdoors & garden
# 17  18           shoes              domestic
# 18  19          sports        games & sports
# 19  20           tools       auto & hardware
# 20  21            toys        games & sports
# 21  22           other       non-categorized

# %% [markdown]
# aggregate functions

# %%
engine.execute("select avg(salary) from employees;").fetchall()
# Out:
# [(Decimal('97433.547801147228'),)]

# %%
engine.execute("select max(salary) from employees;").fetchall()
# Out:
# [(149929,)]

# %%
engine.execute("select min(salary) from employees;").fetchall()
# Out:
# [(40138,)]

# %%
engine.execute("select count(*) from employees;").fetchall()
# Out:
# [(1046,)]

# %%
engine.execute("select count(*), min(salary), max(salary) from employees where region_id = 2;").fetchall()
# Out:
# [(164, 40218, 149221)]

# %%
engine.execute("select count(*), min(id), max(id) from employees;").fetchall()
# Out:
# [(1046, 1, 1944)]

# %% [markdown]
# statistical aggregate functions

# %%
engine.execute("""
        select sum(salary) from employees;
""").fetchall()
# Out:
# [(101915491,)]

# %%
engine.execute("""
        select department_id, sum(salary), avg(salary) from employees group by department_id;
""").fetchall()
# Out:
# [(14, 4039362, Decimal('87812.217391304348')),
#  (8, 5090304, Decimal('103883.755102040816')),
#  (12, 4822205, Decimal('92734.711538461538')),
#  (17, 3274767, Decimal('88507.216216216216')),
#  (1, 4584268, Decimal('99658.000000000000')),
#  (15, 3543027, Decimal('93237.552631578947')),
#  (10, 4651241, Decimal('101113.934782608696')),
#  (11, 4552880, Decimal('98975.652173913043')),
#  (4, 5481063, Decimal('103416.283018867925')),
#  (18, 5378660, Decimal('112055.416666666667')),
#  (16, 3632825, Decimal('100911.805555555556')),
#  (6, 5152963, Decimal('99095.442307692308')),
#  (19, 3968118, Decimal('92281.813953488372')),
#  (2, 4584268, Decimal('99658.000000000000')),
#  (21, 4095808, Decimal('105020.717948717949')),
#  (3, 4218724, Decimal('93749.422222222222')),
#  (20, 3756041, Decimal('93901.025000000000')),
#  (5, 5037890, Decimal('95054.528301886792')),
#  (13, 4366340, Decimal('92900.851063829787')),
#  (22, 8403511, Decimal('95494.443181818182')),
#  (9, 4792085, Decimal('101959.255319148936')),
#  (7, 4489141, Decimal('91615.122448979592'))]

# %%
engine.execute("""
        select
            department_id, sum(salary), round(avg(salary),2)
        from 
            employees
        group by department_id;
""").fetchall()
# Out:
# [(14, 4039362, Decimal('87812.22')),
#  (8, 5090304, Decimal('103883.76')),
#  (12, 4822205, Decimal('92734.71')),
#  (17, 3274767, Decimal('88507.22')),
#  (1, 4584268, Decimal('99658.00')),
#  (15, 3543027, Decimal('93237.55')),
#  (10, 4651241, Decimal('101113.93')),
#  (11, 4552880, Decimal('98975.65')),
#  (4, 5481063, Decimal('103416.28')),
#  (18, 5378660, Decimal('112055.42')),
#  (16, 3632825, Decimal('100911.81')),
#  (6, 5152963, Decimal('99095.44')),
#  (19, 3968118, Decimal('92281.81')),
#  (2, 4584268, Decimal('99658.00')),
#  (21, 4095808, Decimal('105020.72')),
#  (3, 4218724, Decimal('93749.42')),
#  (20, 3756041, Decimal('93901.03')),
#  (5, 5037890, Decimal('95054.53')),
#  (13, 4366340, Decimal('92900.85')),
#  (22, 8403511, Decimal('95494.44')),
#  (9, 4792085, Decimal('101959.26')),
#  (7, 4489141, Decimal('91615.12'))]

# %%
engine.execute(
    """
        select department_id, sum(salary), round(avg(salary),2), var_pop(salary)
        from
        employees
        group by department_id;
    """
).fetchall()
# Out:
# [(14, 4039362, Decimal('87812.22'), Decimal('875256537.77882798')),
#  (8, 5090304, Decimal('103883.76'), Decimal('1040425239.16451479')),
#  (12, 4822205, Decimal('92734.71'), Decimal('1037243300.97448225')),
#  (17, 3274767, Decimal('88507.22'), Decimal('1001696601.52081812')),
#  (1, 4584268, Decimal('99658.00'), Decimal('929902811.86956522')),
#  (15, 3543027, Decimal('93237.55'), Decimal('1072987422.93144044')),
#  (10, 4651241, Decimal('101113.93'), Decimal('1161021316.10444234')),
#  (11, 4552880, Decimal('98975.65'), Decimal('1216304238.79206049')),
#  (4, 5481063, Decimal('103416.28'), Decimal('952478558.54254183')),
#  (18, 5378660, Decimal('112055.42'), Decimal('745849798.45138889')),
#  (16, 3632825, Decimal('100911.81'), Decimal('876898879.10108025')),
#  (6, 5152963, Decimal('99095.44'), Decimal('930175201.51590237')),
#  (19, 3968118, Decimal('92281.81'), Decimal('849306565.17468902')),
#  (2, 4584268, Decimal('99658.00'), Decimal('929902811.86956522')),
#  (21, 4095808, Decimal('105020.72'), Decimal('795868561.02301118')),
#  (3, 4218724, Decimal('93749.42'), Decimal('912220932.82172840')),
#  (20, 3756041, Decimal('93901.03'), Decimal('1049150239.87437500')),
#  (5, 5037890, Decimal('95054.53'), Decimal('1000324590.36240655')),
#  (13, 4366340, Decimal('92900.85'), Decimal('889271955.27569036')),
#  (22, 8403511, Decimal('95494.44'), Decimal('1041669132.04222624')),
#  (9, 4792085, Decimal('101959.26'), Decimal('909562157.08374830')),
#  (7, 4489141, Decimal('91615.12'), Decimal('1073778518.02582257'))]

# %%
engine.execute(
    """
        select
            department_id, sum(salary), round(avg(salary),2), var_pop(salary), stddev_pop(salary)
        from 
            employees
        group by department_id;  
    """
).fetchall()
# Out:
# [(14, 4039362, Decimal('87812.22'), Decimal('875256537.77882798'), Decimal('29584.73487762')),
#  (8, 5090304, Decimal('103883.76'), Decimal('1040425239.16451479'), Decimal('32255.62337275')),
#  (12, 4822205, Decimal('92734.71'), Decimal('1037243300.97448225'), Decimal('32206.26182863')),
#  (17, 3274767, Decimal('88507.22'), Decimal('1001696601.52081812'), Decimal('31649.59085866')),
#  (1, 4584268, Decimal('99658.00'), Decimal('929902811.86956522'), Decimal('30494.30786015')),
#  (15, 3543027, Decimal('93237.55'), Decimal('1072987422.93144044'), Decimal('32756.48673059')),
#  (10, 4651241, Decimal('101113.93'), Decimal('1161021316.10444234'), Decimal('34073.76286976')),
#  (11, 4552880, Decimal('98975.65'), Decimal('1216304238.79206049'), Decimal('34875.55359836')),
#  (4, 5481063, Decimal('103416.28'), Decimal('952478558.54254183'), Decimal('30862.25135246')),
#  (18, 5378660, Decimal('112055.42'), Decimal('745849798.45138889'), Decimal('27310.25079437')),
#  (16, 3632825, Decimal('100911.81'), Decimal('876898879.10108025'), Decimal('29612.47843564')),
#  (6, 5152963, Decimal('99095.44'), Decimal('930175201.51590237'), Decimal('30498.77377069')),
#  (19, 3968118, Decimal('92281.81'), Decimal('849306565.17468902'), Decimal('29142.86473864')),
#  (2, 4584268, Decimal('99658.00'), Decimal('929902811.86956522'), Decimal('30494.30786015')),
#  (21, 4095808, Decimal('105020.72'), Decimal('795868561.02301118'), Decimal('28211.14249766')),
#  (3, 4218724, Decimal('93749.42'), Decimal('912220932.82172840'), Decimal('30202.99542797')),
#  (20, 3756041, Decimal('93901.03'), Decimal('1049150239.87437500'), Decimal('32390.58875467')),
#  (5, 5037890, Decimal('95054.53'), Decimal('1000324590.36240655'), Decimal('31627.90840954')),
#  (13, 4366340, Decimal('92900.85'), Decimal('889271955.27569036'), Decimal('29820.66322662')),
#  (22, 8403511, Decimal('95494.44'), Decimal('1041669132.04222624'), Decimal('32274.89941181')),
#  (9, 4792085, Decimal('101959.26'), Decimal('909562157.08374830'), Decimal('30158.94820918')),
#  (7, 4489141, Decimal('91615.12'), Decimal('1073778518.02582257'), Decimal('32768.55990162'))]

# %%
# pickup 68% 1 std, 95% 2 std
# need video pickup wth round(stddev_pop(salary),2)
engine.execute(
    """
      select
        department_id, 
        sum(salary), 
        round(avg(salary),2), 
        var_pop(salary), 
        round(stddev_pop(salary),2)
    from 
        employees
    group by department_id;
    """
).fetchall()
# Out:
# [(14, 4039362, Decimal('87812.22'), Decimal('875256537.77882798'), Decimal('29584.73')),
#  (8, 5090304, Decimal('103883.76'), Decimal('1040425239.16451479'), Decimal('32255.62')),
#  (12, 4822205, Decimal('92734.71'), Decimal('1037243300.97448225'), Decimal('32206.26')),
#  (17, 3274767, Decimal('88507.22'), Decimal('1001696601.52081812'), Decimal('31649.59')),
#  (1, 4584268, Decimal('99658.00'), Decimal('929902811.86956522'), Decimal('30494.31')),
#  (15, 3543027, Decimal('93237.55'), Decimal('1072987422.93144044'), Decimal('32756.49')),
#  (10, 4651241, Decimal('101113.93'), Decimal('1161021316.10444234'), Decimal('34073.76')),
#  (11, 4552880, Decimal('98975.65'), Decimal('1216304238.79206049'), Decimal('34875.55')),
#  (4, 5481063, Decimal('103416.28'), Decimal('952478558.54254183'), Decimal('30862.25')),
#  (18, 5378660, Decimal('112055.42'), Decimal('745849798.45138889'), Decimal('27310.25')),
#  (16, 3632825, Decimal('100911.81'), Decimal('876898879.10108025'), Decimal('29612.48')),
#  (6, 5152963, Decimal('99095.44'), Decimal('930175201.51590237'), Decimal('30498.77')),
#  (19, 3968118, Decimal('92281.81'), Decimal('849306565.17468902'), Decimal('29142.86')),
#  (2, 4584268, Decimal('99658.00'), Decimal('929902811.86956522'), Decimal('30494.31')),
#  (21, 4095808, Decimal('105020.72'), Decimal('795868561.02301118'), Decimal('28211.14')),
#  (3, 4218724, Decimal('93749.42'), Decimal('912220932.82172840'), Decimal('30203.00')),
#  (20, 3756041, Decimal('93901.03'), Decimal('1049150239.87437500'), Decimal('32390.59')),
#  (5, 5037890, Decimal('95054.53'), Decimal('1000324590.36240655'), Decimal('31627.91')),
#  (13, 4366340, Decimal('92900.85'), Decimal('889271955.27569036'), Decimal('29820.66')),
#  (22, 8403511, Decimal('95494.44'), Decimal('1041669132.04222624'), Decimal('32274.90')),
#  (9, 4792085, Decimal('101959.26'), Decimal('909562157.08374830'), Decimal('30158.95')),
#  (7, 4489141, Decimal('91615.12'), Decimal('1073778518.02582257'), Decimal('32768.56'))]

# %% [markdown]
# grouping and filtering data

# %%
engine.execute(
    """
    select distinct(last_name), department_id, salary
    from employees
    where last_name = 'boyd';
    """
).fetchall()
# Out:
# [('boyd', 5, 108854),
#  ('boyd', 12, 128765),
#  ('boyd', 2, 69936),
#  ('boyd', 1, 69936)]

# %%
engine.execute(
    """
    select distinct(last_name), department_id, salary
    from employees
    where last_name like 'b%%';
    """
).fetchall()
# Out:
# [('burns', 2, 44377),
#  ('burke', 6, 114690),
#  ('bowman', 10, 50623),
#  ('bennett', 15, 71433),
#  ('baker', 13, 145283),
#  ('burns', 14, 88093),
#  ('burns', 7, 102001),
#  ('burton', 19, 67758),
#  ('berry', 5, 43067),
#  ('burns', 18, 113654),
#  ('black', 22, 117171),
#  ('burke', 12, 106033),
#  ('boyd', 1, 69936),
#  ('burke', 9, 95726),
#  ('banks', 17, 43940),
#  ('bishop', 16, 53798),
#  ('black', 22, 80073),
#  ('baker', 8, 68857),
#  ('bell', 21, 92561),
#  ('bailey', 3, 94049),
#  ('bowman', 3, 116355),
#  ('burton', 9, 80763),
#  ('burton', 13, 105810),
#  ('burton', 19, 79172),
#  ('butler', 4, 66313),
#  ('burton', 5, 58697),
#  ('bishop', 14, 69559),
#  ('butler', 2, 128448),
#  ('burton', 8, 140688),
#  ('butler', 8, 115541),
#  ('butler', 12, 47994),
#  ('bell', 3, 66608),
#  ('barnes', 9, 100763),
#  ('barnes', 3, 112837),
#  ('berry', 12, 148640),
#  ('burton', 22, 63682),
#  ('bryant', 17, 139347),
#  ('bell', 20, 68210),
#  ('banks', 6, 137025),
#  ('butler', 1, 128448),
#  ('burke', 10, 147290),
#  ('brooks', 12, 79724),
#  ('butler', 4, 63918),
#  ('bowman', 8, 75399),
#  ('bishop', 21, 110744),
#  ('brooks', 17, 69026),
#  ('banks', 6, 136034),
#  ('baker', 22, 107749),
#  ('burns', 1, 44377),
#  ('bailey', 17, 138540),
#  ('boyd', 12, 128765),
#  ('brooks', 19, 77060),
#  ('burton', 6, 46960),
#  ('bell', 6, 122843),
#  ('brooks', 11, 94502),
#  ('bryant', 18, 148260),
#  ('bradley', 18, 107222),
#  ('bailey', 22, 71676),
#  ('brooks', 22, 102458),
#  ('bryant', 13, 78052),
#  ('boyd', 5, 108854),
#  ('butler', 20, 78157),
#  ('banks', 14, 119747),
#  ('black', 5, 44179),
#  ('bennett', 9, 125713),
#  ('burke', 14, 61446),
#  ('brown', 4, 79419),
#  ('boyd', 2, 69936)]

# %%
engine.execute(
    """
    select distinct(last_name), department_id, salary
    from employees
    where last_name like 'b%%k';
    """
).fetchall()
# Out:
# [('black', 22, 117171), ('black', 5, 44179), ('black', 22, 80073)]

# %%
engine.execute(
    """
    select distinct(last_name), department_id, salary
    from employees
    where last_name like 'b%%k' or salary > 100000;
    """
).fetchall()
# Out:
# [('cooper', 9, 139796),
#  ('morgan', 13, 101945),
#  ('gordon', 16, 142840),
#  ('lopez', 9, 138776),
#  ('rice', 9, 144724),
#  ('matthews', 18, 123936),
#  ('jenkins', 11, 115911),
#  ('hart', 14, 119773),
#  ('cox', 8, 149221),
#  ('ramos', 9, 127268),
#  ('walker', 14, 145281),
#  ('lane', 18, 104896),
#  ('castillo', 6, 132634),
#  ('kelly', 19, 128646),
#  ('james', 5, 136377),
#  ('elliott', 5, 119097),
#  ('walker', 8, 134488),
#  ('morales', 12, 149598),
#  ('torres', 1, 120875),
#  ('torres', 6, 118307),
#  ('collins', 4, 137911),
#  ('marshall', 6, 123401),
#  ('lawrence', 10, 131681),
#  ('hudson', 22, 146745),
#  ('medina', 13, 102149),
#  ('myers', 12, 139060),
#  ('hughes', 15, 122110),
#  ('sullivan', 17, 101756),
#  ('webb', 1, 111689),
#  ('anderson', 2, 126485),
#  ('larson', 18, 119414),
#  ('henry', 19, 131252),
#  ('elliott', 16, 100570),
#  ('owens', 4, 138682),
#  ('gutierrez', 9, 106994),
#  ('wallace', 22, 118793),
#  ('black', 22, 80073),
#  ('schmidt', 1, 133612),
#  ('tucker', 10, 104844),
#  ('ellis', 13, 134074),
#  ('meyer', 20, 145363),
#  ('gonzalez', 21, 131830),
#  ('robertson', 6, 136406),
#  ('murphy', 12, 146432),
#  ('gonzales', 16, 131274),
#  ('harris', 22, 126468),
#  ('simmons', 16, 113857),
#  ('george', 2, 141505),
#  ('white', 6, 122540),
#  ('rodriguez', 4, 141949),
#  ('sanchez', 16, 108093),
#  ('webb', 18, 144932),
#  ('gordon', 2, 129324),
#  ('crawford', 4, 114436),
#  ('kelley', 5, 116266),
#  ('parker', 8, 114919),
#  ('frazier', 15, 111244),
#  ('moreno', 22, 121238),
#  ('reed', 1, 126001),
#  ('cunningham', 18, 108248),
#  ('duncan', 19, 110407),
#  ('hawkins', 2, 115506),
#  ('harris', 16, 129527),
#  ('knight', 16, 100716),
#  ('sanders', 13, 117905),
#  ('garrett', 7, 145181),
#  ('hansen', 9, 129746),
#  ('moreno', 13, 140858),
#  ('owens', 22, 104373),
#  ('kelly', 9, 144965),
#  ('ford', 13, 138459),
#  ('little', 17, 114647),
#  ('greene', 22, 149835),
#  ('rice', 10, 108380),
#  ('watson', 13, 115679),
#  ('carter', 10, 120800),
#  ('watson', 22, 111873),
#  ('ortiz', 1, 113231),
#  ('edwards', 10, 115360),
#  ('hunt', 17, 140430),
#  ('chavez', 17, 137704),
#  ('peters', 4, 132470),
#  ('butler', 1, 128448),
#  ('robinson', 17, 144608),
#  ('phillips', 5, 128205),
#  ('hansen', 22, 145559),
#  ('snyder', 8, 143846),
#  ('phillips', 9, 127367),
#  ('harris', 21, 148940),
#  ('gordon', 2, 136448),
#  ('young', 17, 114695),
#  ('baker', 22, 107749),
#  ('cruz', 11, 131479),
#  ('mcdonald', 1, 111041),
#  ('torres', 8, 135886),
#  ('simmons', 4, 116767),
#  ('lynch', 18, 117248),
#  ('schmidt', 20, 125465),
#  ('bailey', 17, 138540),
#  ('washington', 5, 148408),
#  ('turner', 19, 130849),
#  ('greene', 5, 104517),
#  ('cole', 14, 133040),
#  ('arnold', 22, 133781),
#  ('stanley', 13, 140850),
#  ('watkins', 22, 104444),
#  ('harvey', 21, 138179),
#  ('jordan', 20, 123843),
#  ('sanchez', 1, 146167),
#  ('peterson', 18, 144841),
#  ('williamson', 6, 149085),
#  ('carpenter', 12, 134813),
#  ('anderson', 20, 115009),
#  ('wheeler', 22, 145284),
#  ('boyd', 5, 108854),
#  ('lee', 14, 117147),
#  ('carroll', 3, 125398),
#  ('hernandez', 8, 119787),
#  ('dixon', 3, 138970),
#  ('black', 5, 44179),
#  ('bennett', 9, 125713),
#  ('edwards', 18, 121713),
#  ('powell', 4, 116013),
#  ('richards', 5, 116333),
#  ('gonzalez', 11, 107240),
#  ('lee', 13, 115085),
#  ('washington', 15, 109828),
#  ('lynch', 5, 111318),
#  ('rivera', 22, 122219),
#  ('frazier', 21, 104326),
#  ('hill', 21, 144661),
#  ('watkins', 20, 133507),
#  ('weaver', 16, 120226),
#  ('day', 3, 125914),
#  ('freeman', 15, 109154),
#  ('owens', 1, 135326),
#  ('harvey', 4, 124707),
#  ('burns', 7, 102001),
#  ('lawson', 1, 130993),
#  ('rose', 10, 120225),
#  ('powell', 11, 120577),
#  ('james', 14, 108657),
#  ('coleman', 6, 110839),
#  ('reyes', 9, 134114),
#  ('andrews', 4, 142103),
#  ('burns', 18, 113654),
#  ('larson', 22, 144991),
#  ('burke', 12, 106033),
#  ('sanders', 16, 146970),
#  ('harris', 16, 110912),
#  ('kelly', 8, 120086),
#  ('mills', 10, 114200),
#  ('nichols', 1, 110589),
#  ('jordan', 5, 133498),
#  ('dixon', 20, 126420),
#  ('carr', 2, 101768),
#  ('gonzalez', 10, 148106),
#  ('wilson', 4, 122446),
#  ('williamson', 5, 118602),
#  ('james', 5, 130188),
#  ('peters', 10, 132037),
#  ('rice', 22, 145747),
#  ('hanson', 11, 133492),
#  ('reed', 16, 120579),
#  ('stanley', 10, 149929),
#  ('harrison', 3, 134334),
#  ('robertson', 6, 106607),
#  ('butler', 8, 115541),
#  ('cook', 17, 109404),
#  ('stephens', 10, 147440),
#  ('riley', 14, 149114),
#  ('rivera', 8, 137281),
#  ('stevens', 7, 118791),
#  ('schmidt', 2, 121300),
#  ('garza', 7, 113278),
#  ('cox', 8, 135719),
#  ('palmer', 22, 138815),
#  ('lopez', 11, 125944),
#  ('weaver', 13, 131283),
#  ('day', 12, 135993),
#  ('gonzales', 2, 101006),
#  ('morris', 12, 131662),
#  ('chavez', 15, 139163),
#  ('watkins', 6, 125668),
#  ('hanson', 20, 141513),
#  ('kelley', 7, 106602),
#  ('coleman', 4, 121378),
#  ('gonzales', 5, 127393),
#  ('walker', 12, 120085),
#  ('lopez', 18, 131961),
#  ('mason', 21, 120160),
#  ('edwards', 2, 140194),
#  ('spencer', 7, 110881),
#  ('carpenter', 6, 125523),
#  ('wright', 1, 127521),
#  ('hamilton', 7, 141340),
#  ('burke', 10, 147290),
#  ('welch', 18, 118514),
#  ('chavez', 9, 128766),
#  ('price', 11, 142794),
#  ('lawrence', 18, 133424),
#  ('murray', 11, 142255),
#  ('morris', 16, 127645),
#  ('ross', 8, 104671),
#  ('stanley', 7, 103237),
#  ('thompson', 16, 133281),
#  ('thomas', 2, 116487),
#  ('banks', 6, 136034),
#  ('moore', 6, 139304),
#  ('allen', 21, 149586),
#  ('murphy', 22, 128105),
#  ('kennedy', 22, 111072),
#  ('anderson', 22, 139486),
#  ('carpenter', 6, 124418),
#  ('kennedy', 20, 100741),
#  ('parker', 13, 136917),
#  ('freeman', 5, 147868),
#  ('allen', 10, 132998),
#  ('griffin', 9, 101875),
#  ('ray', 22, 126661),
#  ('white', 9, 118834),
#  ('bradley', 18, 107222),
#  ('brooks', 22, 102458),
#  ('olson', 5, 107535),
#  ('chavez', 10, 116894),
#  ('king', 7, 149597),
#  ('morgan', 15, 148952),
#  ('long', 8, 142529),
#  ('alexander', 2, 144724),
#  ('carr', 16, 115274),
#  ('jordan', 22, 115776),
#  ('wright', 5, 107727),
#  ('moreno', 4, 123017),
#  ('fuller', 11, 142967),
#  ('anderson', 12, 122272),
#  ('carroll', 2, 128885),
#  ('nguyen', 2, 108378),
#  ('reynolds', 6, 120138),
#  ('graham', 8, 109058),
#  ('ryan', 4, 115888),
#  ('gutierrez', 12, 139845),
#  ('phillips', 21, 118497),
#  ('mcdonald', 3, 141464),
#  ('torres', 14, 105686),
#  ('henry', 8, 132421),
#  ('carpenter', 18, 133360),
#  ('elliott', 20, 131409),
#  ('hawkins', 20, 134931),
#  ('griffin', 16, 116480),
#  ('mcdonald', 2, 111041),
#  ('fowler', 18, 104264),
#  ('burke', 6, 114690),
#  ('fowler', 18, 120540),
#  ('nelson', 19, 139564),
#  ('white', 5, 147702),
#  ('dunn', 18, 148889),
#  ('white', 10, 122130),
#  ('hunter', 22, 123156),
#  ('gonzalez', 11, 106833),
#  ('reed', 19, 142483),
#  ('baker', 13, 145283),
#  ('graham', 4, 123391),
#  ('freeman', 15, 149351),
#  ('sanchez', 2, 146167),
#  ('willis', 21, 113507),
#  ('lawrence', 18, 108748),
#  ('hansen', 4, 113893),
#  ('roberts', 17, 105319),
#  ('weaver', 6, 126307),
#  ('cole', 21, 116766),
#  ('larson', 18, 125574),
#  ('freeman', 19, 121296),
#  ('sims', 10, 136790),
#  ('johnson', 7, 135001),
#  ('hanson', 7, 144767),
#  ('garcia', 11, 135132),
#  ('jenkins', 21, 113599),
#  ('kelley', 16, 110660),
#  ('johnston', 14, 123820),
#  ('cole', 4, 117962),
#  ('lewis', 22, 115975),
#  ('elliott', 22, 104149),
#  ('hawkins', 7, 144073),
#  ('warren', 16, 126201),
#  ('ellis', 11, 139775),
#  ('ortiz', 2, 113231),
#  ('rose', 5, 107207),
#  ('bowman', 3, 116355),
#  ('chapman', 14, 126103),
#  ('burton', 13, 105810),
#  ('butler', 2, 128448),
#  ('reyes', 9, 148860),
#  ('carpenter', 4, 101653),
#  ('crawford', 12, 119471),
#  ('gordon', 1, 136448),
#  ('jackson', 4, 107093),
#  ('gomez', 4, 107389),
#  ('chapman', 4, 110749),
#  ('carroll', 8, 128562),
#  ('peterson', 22, 104530),
#  ('barnes', 9, 100763),
#  ('sims', 20, 127223),
#  ('evans', 6, 106535),
#  ('stevens', 6, 106229),
#  ('clark', 11, 112510),
#  ('berry', 12, 148640),
#  ('vasquez', 4, 131811),
#  ('schmidt', 2, 133612),
#  ('elliott', 13, 125115),
#  ('young', 10, 138844),
#  ('andrews', 18, 147003),
#  ('griffin', 8, 140567),
#  ('carroll', 12, 110622),
#  ('banks', 6, 137025),
#  ('rodriguez', 18, 140276),
#  ('hayes', 4, 130097),
#  ('vasquez', 9, 127695),
#  ('moreno', 19, 102493),
#  ('wright', 19, 109233),
#  ('wagner', 4, 135445),
#  ('clark', 20, 146611),
#  ('george', 1, 141505),
#  ('johnston', 11, 143855),
#  ('myers', 10, 148993),
#  ('walker', 6, 122108),
#  ('moreno', 12, 107907),
#  ('ellis', 18, 146256),
#  ('gordon', 1, 129324),
#  ('rose', 3, 127291),
#  ('gibson', 6, 109449),
#  ('fox', 15, 128726),
#  ('riley', 20, 143781),
#  ('chapman', 13, 125843),
#  ('richardson', 11, 145962),
#  ('bishop', 21, 110744),
#  ('reed', 2, 126001),
#  ('sullivan', 11, 103182),
#  ('olson', 12, 110411),
#  ('dean', 16, 140708),
#  ('hawkins', 1, 115506),
#  ('stevens', 22, 108444),
#  ('payne', 22, 138137),
#  ('williams', 3, 131273),
#  ('webb', 15, 142988),
#  ('fowler', 11, 142211),
#  ('gibson', 13, 148816),
#  ('ward', 17, 108228),
#  ('dixon', 11, 104224),
#  ('reed', 18, 108504),
#  ('boyd', 12, 128765),
#  ('woods', 7, 148986),
#  ('williams', 14, 101599),
#  ('bryant', 18, 148260),
#  ('robertson', 6, 136492),
#  ('robinson', 7, 134422),
#  ('gomez', 21, 103806),
#  ('jones', 3, 128048),
#  ('torres', 2, 120875),
#  ('webb', 21, 143595),
#  ('hall', 15, 112126),
#  ('austin', 19, 101646),
#  ('williams', 21, 107709),
#  ('harrison', 19, 133845),
#  ('medina', 8, 114989),
#  ('reynolds', 15, 111427),
#  ('hall', 18, 100428),
#  ('fowler', 3, 110383),
#  ('anderson', 1, 126485),
#  ('webb', 2, 111689),
#  ('morales', 8, 101855),
#  ('garcia', 10, 131075),
#  ('turner', 10, 146952),
#  ('fields', 22, 101520),
#  ('tucker', 3, 148573),
#  ('grant', 6, 108441),
#  ('peters', 10, 138093),
#  ('porter', 19, 140243),
#  ('walker', 19, 110896),
#  ('hayes', 15, 110615),
#  ('snyder', 16, 109004),
#  ('armstrong', 4, 143853),
#  ('crawford', 12, 140996),
#  ('stewart', 6, 149336),
#  ('lynch', 11, 126683),
#  ('hill', 19, 117092),
#  ('webb', 14, 127569),
#  ('hunter', 19, 112048),
#  ('austin', 12, 110627),
#  ('alexander', 1, 144724),
#  ('collins', 18, 143034),
#  ('henderson', 21, 101937),
#  ('medina', 3, 106659),
#  ('matthews', 11, 114970),
#  ('nguyen', 1, 108378),
#  ('knight', 17, 135688),
#  ('carroll', 1, 128885),
#  ('foster', 11, 138478),
#  ('gordon', 18, 107407),
#  ('castillo', 14, 130188),
#  ('black', 22, 117171),
#  ('spencer', 22, 119769),
#  ('cole', 21, 133190),
#  ('reed', 9, 144953),
#  ('richards', 3, 140004),
#  ('moreno', 10, 112004),
#  ('daniels', 21, 139061),
#  ('stewart', 22, 148144),
#  ('willis', 9, 123427),
#  ('kelley', 19, 120377),
#  ('richardson', 5, 142403),
#  ('long', 4, 149099),
#  ('carr', 9, 143570),
#  ('gomez', 16, 101582),
#  ('diaz', 11, 128748),
#  ('howard', 18, 141753),
#  ('edwards', 1, 140194),
#  ('kelly', 15, 143433),
#  ('ramos', 4, 102361),
#  ('mendoza', 4, 128947),
#  ('martinez', 18, 131392),
#  ('hanson', 21, 113354),
#  ('reyes', 20, 130563),
#  ('thomas', 21, 128239),
#  ('white', 4, 136356),
#  ('williamson', 8, 145575),
#  ('snyder', 15, 141678),
#  ('washington', 18, 113311),
#  ('wright', 2, 127521),
#  ('burton', 8, 140688),
#  ('harvey', 4, 131816),
#  ('gibson', 6, 105444),
#  ('perry', 13, 124296),
#  ('gonzalez', 6, 122231),
#  ('cooper', 7, 120108),
#  ('martinez', 8, 124853),
#  ('stevens', 8, 106729),
#  ('phillips', 22, 102793),
#  ('thomas', 1, 116487),
#  ('dixon', 3, 106281),
#  ('snyder', 10, 124215),
#  ('gray', 5, 134205),
#  ('reynolds', 9, 121836),
#  ('barnes', 3, 112837),
#  ('spencer', 8, 143223),
#  ('holmes', 22, 147150),
#  ('turner', 8, 127875),
#  ('stephens', 10, 110366),
#  ('ramirez', 22, 147862),
#  ('jacobs', 14, 121966),
#  ('carr', 1, 101768),
#  ('matthews', 22, 119602),
#  ('howard', 3, 148687),
#  ('crawford', 9, 142149),
#  ('kelly', 15, 132676),
#  ('bryant', 17, 139347),
#  ('williamson', 21, 135695),
#  ('ford', 19, 147739),
#  ('fisher', 4, 131152),
#  ('phillips', 7, 127171),
#  ('ruiz', 18, 116301),
#  ('jacobs', 8, 141139),
#  ('welch', 17, 133007),
#  ('ferguson', 21, 119385),
#  ('moore', 4, 142101),
#  ('perry', 22, 146701),
#  ('moore', 7, 102395),
#  ('wagner', 22, 142516),
#  ('robinson', 11, 137594),
#  ('cunningham', 9, 139302),
#  ('schmidt', 1, 121300),
#  ('day', 7, 109890),
#  ('sims', 5, 146024),
#  ('gonzales', 1, 101006),
#  ('harper', 18, 144639),
#  ('ramirez', 7, 112929),
#  ('nichols', 8, 145692),
#  ('young', 5, 104079),
#  ('knight', 7, 125847),
#  ('hudson', 12, 143226),
#  ('arnold', 16, 135786),
#  ('sanders', 13, 102211),
#  ('franklin', 16, 117105),
#  ('bell', 6, 122843),
#  ('vasquez', 8, 125378),
#  ('johnson', 6, 134940),
#  ('alexander', 22, 140078),
#  ('owens', 2, 135326),
#  ('parker', 18, 148906),
#  ('griffin', 22, 108970),
#  ('day', 21, 129890),
#  ('hudson', 3, 103845),
#  ('price', 5, 133091),
#  ('roberts', 5, 139714),
#  ('lawson', 2, 130993),
#  ('woods', 4, 123995),
#  ('evans', 8, 122595),
#  ('banks', 14, 119747),
#  ('chavez', 10, 144028),
#  ('hamilton', 11, 141375),
#  ('mason', 20, 147166),
#  ('stone', 9, 100746),
#  ('watkins', 14, 128617),
#  ('watkins', 18, 128805),
#  ('gordon', 3, 110058),
#  ('nichols', 2, 110589)]

# %% [markdown]
# joining and filtering data

# %%
engine.execute(
    """
    select * 
    from employees e
    join company_regions cr
    on e.region_id = cr.id
    limit 5;
    """
).fetchall()
# Out:
# [(1, 'kelley', 'rkelley0@soundcloud.com', datetime.date(2015, 9, 19), 67470, 'structural engineer', 2, 6, 2, 'southeast', 'usa'),
#  (22, 'alexander', 'kalexanderl@marketwatch.com', datetime.date(2021, 10, 20), 144724, 'marketing assistant', 2, 1, 2, 'southeast', 'usa'),
#  (1003, 'carr', 'fcarr2@woothemes.com', datetime.date(2018, 9, 20), 101768, 'recruiting manager', 3, 1, 3, 'northwest', 'usa'),
#  (45, 'nguyen', 'mnguyen18@biblegateway.com', datetime.date(2021, 6, 21), 108378, 'electrical engineer', 7, 1, 7, 'nova scotia', 'canada'),
#  (50, 'armstrong', 'parmstrong1d@hc360.com', datetime.date(2017, 9, 13), 89969, 'senior editor', 4, 1, 4, 'southwest', 'usa')]

# %%
engine.execute(
    """
    select
        e.*, cr.region_name, cr.country_name
    from employees e
    join
        company_regions cr
    on e.region_id = cr.id limit 5;
    """
).fetchall()
# Out:
# [(1, 'kelley', 'rkelley0@soundcloud.com', datetime.date(2015, 9, 19), 67470, 'structural engineer', 2, 6, 'southeast', 'usa'),
#  (22, 'alexander', 'kalexanderl@marketwatch.com', datetime.date(2021, 10, 20), 144724, 'marketing assistant', 2, 1, 'southeast', 'usa'),
#  (1003, 'carr', 'fcarr2@woothemes.com', datetime.date(2018, 9, 20), 101768, 'recruiting manager', 3, 1, 'northwest', 'usa'),
#  (45, 'nguyen', 'mnguyen18@biblegateway.com', datetime.date(2021, 6, 21), 108378, 'electrical engineer', 7, 1, 'nova scotia', 'canada'),
#  (50, 'armstrong', 'parmstrong1d@hc360.com', datetime.date(2017, 9, 13), 89969, 'senior editor', 4, 1, 'southwest', 'usa')]

# %%
engine.execute(
    """
    select
        e.*, cr.region_name, cr.country_name
    from employees e
    join
        company_regions cr
    on e.region_id = cr.id
    where cr.country_name = 'canada'
    limit 10;
    """
).fetchall()
# Out:
# [(45, 'nguyen', 'mnguyen18@biblegateway.com', datetime.date(2021, 6, 21), 108378, 'electrical engineer', 7, 1, 'nova scotia', 'canada'),
#  (62, 'boyd', 'aboyd1p@artisteer.com', datetime.date(2022, 7, 4), 69936, 'senior editor', 7, 1, 'nova scotia', 'canada'),
#  (92, 'ortiz', 'aortiz2j@jigsy.com', datetime.date(2020, 7, 17), 113231, 'senior editor', 7, 1, 'nova scotia', 'canada'),
#  (103, 'reed', 'dreed2u@arstechnica.com', datetime.date(2016, 12, 19), 126001, 'structural engineer', 6, 1, 'quebec', 'canada'),
#  (292, 'ortiz', 'dortiz83@themeforest.net', datetime.date(2017, 12, 25), 91296, 'environmental tech', 6, 1, 'quebec', 'canada'),
#  (327, 'edwards', 'medwards92@mail.ru', datetime.date(2021, 9, 30), 140194, 'programmer iv', 5, 1, 'british columbia', 'canada'),
#  (378, 'nichols', 'bnicholsah@networkadvertising.org', datetime.date(2020, 7, 8), 110589, 'cost accountant', 7, 1, 'nova scotia', 'canada'),
#  (385, 'carroll', 'ecarrollao@newsvine.com', datetime.date(2015, 5, 9), 128885, 'office assistant iii', 5, 1, 'british columbia', 'canada'),
#  (453, 'anderson', 'aandersonck@whitehouse.gov', datetime.date(2019, 8, 5), 126485, 'computer systems analyst i', 6, 1, 'quebec', 'canada'),
#  (460, 'sanchez', 'lsanchezcr@rediff.com', datetime.date(2019, 11, 18), 146167, 'assistant professor', 5, 1, 'british columbia', 'canada')]

# %%
engine.execute(
    """
    select
    e.last_name,
    e.email,
    e.start_date,
    e.salary,
    e.job_title,
    cr.region_name, 
    cr.country_name
    from
        employees e
    join
        company_regions cr
    on
        e.region_id = cr.id
    where
        cr.country_name = 'canada'
    limit 10;
    """
).fetchall()
# Out:
# [('nguyen', 'mnguyen18@biblegateway.com', datetime.date(2021, 6, 21), 108378, 'electrical engineer', 'nova scotia', 'canada'),
#  ('boyd', 'aboyd1p@artisteer.com', datetime.date(2022, 7, 4), 69936, 'senior editor', 'nova scotia', 'canada'),
#  ('ortiz', 'aortiz2j@jigsy.com', datetime.date(2020, 7, 17), 113231, 'senior editor', 'nova scotia', 'canada'),
#  ('reed', 'dreed2u@arstechnica.com', datetime.date(2016, 12, 19), 126001, 'structural engineer', 'quebec', 'canada'),
#  ('ortiz', 'dortiz83@themeforest.net', datetime.date(2017, 12, 25), 91296, 'environmental tech', 'quebec', 'canada'),
#  ('edwards', 'medwards92@mail.ru', datetime.date(2021, 9, 30), 140194, 'programmer iv', 'british columbia', 'canada'),
#  ('nichols', 'bnicholsah@networkadvertising.org', datetime.date(2020, 7, 8), 110589, 'cost accountant', 'nova scotia', 'canada'),
#  ('carroll', 'ecarrollao@newsvine.com', datetime.date(2015, 5, 9), 128885, 'office assistant iii', 'british columbia', 'canada'),
#  ('anderson', 'aandersonck@whitehouse.gov', datetime.date(2019, 8, 5), 126485, 'computer systems analyst i', 'quebec', 'canada'),
#  ('sanchez', 'lsanchezcr@rediff.com', datetime.date(2019, 11, 18), 146167, 'assistant professor', 'british columbia', 'canada')]

# %% [markdown]
# DATA MUNGING WITH SQL

# %%
engine.execute("select upper(department_name) from company_departments;").fetchall()
# Out:
# [('AUTOMOTIVE',),
#  ('BABY',),
#  ('BEAUTY',),
#  ('CLOTHING',),
#  ('COMPUTERS',),
#  ('ELECTRONICS',),
#  ('GAMES',),
#  ('GARDEN',),
#  ('GROCERY',),
#  ('HEALTH',),
#  ('HOME',),
#  ('INDUSTRIAL',),
#  ('JEWELERY',),
#  ('KIDS',),
#  ('MOVIES',),
#  ('MUSIC',),
#  ('OUTDOORS',),
#  ('SHOES',),
#  ('SPORTS',),
#  ('TOOLS',),
#  ('TOYS',),
#  ('OTHER',)]

# %%
engine.execute("select initcap(department_name) from company_departments;").fetchall()
# Out:
# [('Automotive',),
#  ('Baby',),
#  ('Beauty',),
#  ('Clothing',),
#  ('Computers',),
#  ('Electronics',),
#  ('Games',),
#  ('Garden',),
#  ('Grocery',),
#  ('Health',),
#  ('Home',),
#  ('Industrial',),
#  ('Jewelery',),
#  ('Kids',),
#  ('Movies',),
#  ('Music',),
#  ('Outdoors',),
#  ('Shoes',),
#  ('Sports',),
#  ('Tools',),
#  ('Toys',),
#  ('Other',)]

# %%
engine.execute("select lower(initcap(department_name)) from company_departments;").fetchall()
# Out:
# [('automotive',),
#  ('baby',),
#  ('beauty',),
#  ('clothing',),
#  ('computers',),
#  ('electronics',),
#  ('games',),
#  ('garden',),
#  ('grocery',),
#  ('health',),
#  ('home',),
#  ('industrial',),
#  ('jewelery',),
#  ('kids',),
#  ('movies',),
#  ('music',),
#  ('outdoors',),
#  ('shoes',),
#  ('sports',),
#  ('tools',),
#  ('toys',),
#  ('other',)]

# %%
engine.execute("select ' kelly';").fetchall()
# Out:
# [(' kelly',)]

# %%
engine.execute("select ' kelly' = 'kelly';").fetchall()
# Out:
# [(False,)]

# %%
engine.execute("select 'TRUE' = 'true';").fetchall()
# Out:
# [(False,)]

# %%
engine.execute("select job_title || last_name from employees;").fetchall()
# Out:
# [('structural engineerkelley',),
#  ('marketing assistantalexander',),
#  ('recruiting managercarr',),
#  ('electrical engineernguyen',),
#  ('senior editorarmstrong',),
#  ('environmental techross',),
#  ('senior editorboyd',),
#  ('tax accountantjordan',),
#  ('senior editorortiz',),
#  ('structural engineerreed',),
#  ('assistant managerfox',),
#  ('administrative officerlawson',),
#  ('analyst programmermorris',),
#  ('vp product managementschmidt',),
#  ('software consultanttorres',),
#  ('environmental techortiz',),
#  ('programmer ivedwards',),
#  ('desktop support techniciangutierrez',),
#  ('marketing assistantjenkins',),
#  ('community outreach specialisthall',),
#  ('cost accountantnichols',),
#  ('office assistant iiicarroll',),
#  ('computer systems analyst ianderson',),
#  ('product engineerhawkins',),
#  ('assistant professorsanchez',),
#  ('associate professorgeorge',),
#  ('electrical engineerduncan',),
#  ('vp salesmarshall',),
#  ('recruiting managermcdonald',),
#  ('community outreach specialistfoster',),
#  ('administrative assistant iiimorales',),
#  ('software test engineer irose',),
#  ('biostatistician isimmons',),
#  ('developer igordon',),
#  ('programmer ivmeyer',),
#  ('graphic designerthomas',),
#  ('human resources assistant iischmidt',),
#  ('technical writerburns',),
#  ('technical writerbutler',),
#  ('media manager iigordon',),
#  ('nursewright',),
#  ('sales associategonzales',),
#  ('graphic designerowens',),
#  ('gis technical architectwebb',),
#  ('research assistant iimcdonald',),
#  ('pharmacistpeterson',),
#  ('vp product managementadams',),
#  ('recruiting managercarr',),
#  ('marketing assistantalexander',),
#  ('electrical engineernguyen',),
#  ('senior editorarmstrong',),
#  ('environmental techross',),
#  ('senior editorboyd',),
#  ('tax accountantjordan',),
#  ('senior editorortiz',),
#  ('structural engineerreed',),
#  ('assistant managerfox',),
#  ('administrative officerlawson',),
#  ('analyst programmermorris',),
#  ('vp product managementschmidt',),
#  ('software consultanttorres',),
#  ('environmental techortiz',),
#  ('programmer ivedwards',),
#  ('desktop support techniciangutierrez',),
#  ('marketing assistantjenkins',),
#  ('community outreach specialisthall',),
#  ('cost accountantnichols',),
#  ('office assistant iiicarroll',),
#  ('computer systems analyst ianderson',),
#  ('product engineerhawkins',),
#  ('assistant professorsanchez',),
#  ('associate professorgeorge',),
#  ('electrical engineerduncan',),
#  ('vp salesmarshall',),
#  ('recruiting managermcdonald',),
#  ('community outreach specialistfoster',),
#  ('administrative assistant iiimorales',),
#  ('software test engineer irose',),
#  ('biostatistician isimmons',),
#  ('developer igordon',),
#  ('programmer ivmeyer',),
#  ('graphic designerthomas',),
#  ('human resources assistant iischmidt',),
#  ('technical writerburns',),
#  ('technical writerbutler',),
#  ('media manager iigordon',),
#  ('nursewright',),
#  ('sales associategonzales',),
#  ('graphic designerowens',),
#  ('gis technical architectwebb',),
#  ('research assistant iimcdonald',),
#  ('pharmacistpeterson',),
#  ('vp product managementadams',),
#  ('compensation analystschmidt',),
#  ('web developer iiimedina',),
#  ('civil engineerkennedy',),
#  ('web developer iiiallen',),
#  ('senior developerdixon',),
#  ('operatorvasquez',),
#  ('registered nursewallace',),
#  ('operatormoore',),
#  ('librarianwagner',),
#  ('clinical specialistbarnes',),
#  ('junior executiveday',),
#  ('data coordiatorsanders',),
#  ('tax accountanttucker',),
#  ('programmer ivmcdonald',),
#  ('marketing assistantortiz',),
#  ('sales representativeward',),
#  ('analog circuit design managervasquez',),
#  ('graphic designerprice',),
#  ('database administrator iiilewis',),
#  ('accounting assistant iiirose',),
#  ('occupational therapistreed',),
#  ('assistant media plannerallen',),
#  ('nurse practicionerhudson',),
#  ('programmer iiijones',),
#  ('software test engineer isims',),
#  ('administrative officerscott',),
#  ('senior editorhoward',),
#  ('analyst programmerrichards',),
#  ('senior quality engineermorgan',),
#  ('assistant professorcarroll',),
#  ('general managerbell',),
#  ('business systems development analystgordon',),
#  ('structural analysis engineerdixon',),
#  ('accountant iiharrison',),
#  ('chief design engineerfowler',),
#  ('nurse practicionertucker',),
#  ('analyst programmermurphy',),
#  ('account executivehowell',),
#  ('design engineerrichards',),
#  ('design engineermiller',),
#  ('web developer ivwilliams',),
#  ('structural engineerbowman',),
#  ('senior financial analystbailey',),
#  ('quality control specialistmedina',),
#  ('general managerhoward',),
#  ('account representative iiiweaver',),
#  ('product engineerrodriguez',),
#  ('web developer icoleman',),
#  ('accounting assistant imason',),
#  ('accountant ivrose',),
#  ('office assistant ivhayes',),
#  ('tax accountantpowell',),
#  ('accounting assistant ivrivera',),
#  ('business systems development analystlewis',),
#  ('associate professorandrews',),
#  ('paralegalstephens',),
#  ('computer systems analyst iiiramos',),
#  ('structural engineerbutler',),
#  ('database administrator iipeters',),
#  ('employees accountant iiiwashington',),
#  ('food chemistbutler',),
#  ('technical writermorgan',),
#  ('senior developerbrown',),
#  ('quality control specialistandrews',),
#  ('community outreach specialistgomez',),
#  ('financial advisorgraham',),
#  ('electrical engineerlynch',),
#  ('teachercoleman',),
#  ('teacherford',),
#  ('registered nurseharvey',),
#  ('executive secretarylong',),
#  ('office assistant ivwhite',),
#  ('clinical specialisthansen',),
#  ('assistant media plannerwoods',),
#  ('operatorwagner',),
#  ('analyst programmerowens',),
#  ('computer systems analyst ihunt',),
#  ('sales representativeharvey',),
#  ('electrical engineerjackson',),
#  ('web designer iicarpenter',),
#  ('help desk operatormendoza',),
#  ('quality engineerjones',),
#  ('social workervasquez',),
#  ('account representative ivcrawford',),
#  ('marketing managerreid',),
#  ('database administrator ivfisher',),
#  ('design engineerarmstrong',),
#  ('vp product managementgutierrez',),
#  ('paralegalmoore',),
#  ('computer systems analyst ivwatkins',),
#  ('systems administrator iiwilson',),
#  ('mechanical systems engineerlawson',),
#  ('speech pathologistmoreno',),
#  ('legal assistantchapman',),
#  ('accountant ivcollins',),
#  ('environmental techsimmons',),
#  ('librarianryan',),
#  ('accountant iiicole',),
#  ('data coordiatorblack',),
#  ('quality engineerprice',),
#  ('quality engineerhawkins',),
#  ('software engineer iiioliver',),
#  ('junior executivecunningham',),
#  ('senior cost accountantperkins',),
#  ('general managerfreeman',),
#  ('graphic designernguyen',),
#  ('speech pathologistwashington',),
#  ('financial advisorfisher',),
#  ('compensation analystferguson',),
#  ('health coach iiiwatson',),
#  ('sales associateday',),
#  ('web developer iirose',),
#  ('engineer iiirichardson',),
#  ('research assistant iberry',),
#  ('vp product managementarnold',),
#  ('nuclear power engineerjordan',),
#  ('computer systems analyst iwright',),
#  ('help desk techniciangonzales',),
#  ('systems administrator ivyoung',),
#  ('vp quality controlwhite',),
#  ('recruitermarshall',),
#  ('structural analysis engineerortiz',),
#  ('senior editorboyd',),
#  ('biostatistician igray',),
#  ('human resources assistant igomez',),
#  ('director of saleswilliamson',),
#  ('senior developerrichards',),
#  ('administrative officerkim',),
#  ('software engineer ijames',),
#  ('assistant media plannertaylor',),
#  ('technical writerlynch',),
#  ('research assistant iiigreene',),
#  ('marketing assistantalexander',),
#  ('sales representativephillips',),
#  ('sales representativereid',),
#  ('vp accountingprice',),
#  ('geological engineerroberts',),
#  ('information systems managerhill',),
#  ('senior cost accountantmurray',),
#  ('legal assistantrichards',),
#  ('administrative assistant ielliott',),
#  ('office assistant iiiolson',),
#  ('structural analysis engineerjames',),
#  ('actuarysims',),
#  ('operatorknight',),
#  ('help desk operatorroberts',),
#  ('marketing assistantkelley',),
#  ('cost accountantrice',),
#  ('vp product managementmarshall',),
#  ('teacherburton',),
#  ('media manager irichards',),
#  ('dental hygienistwilliamson',),
#  ('software test engineer iiiwebb',),
#  ('executive secretarywatkins',),
#  ('financial advisorjohnson',),
#  ('automation specialist icoleman',),
#  ('civil engineercastillo',),
#  ('help desk operatoraustin',),
#  ('engineer iigibson',),
#  ('nursegrant',),
#  ('information systems managerwheeler',),
#  ('automation specialist irobertson',),
#  ('electrical engineerwest',),
#  ('human resources assistant iigibson',),
#  ('software engineer iiiwilliamson',),
#  ('computer systems analyst imarshall',),
#  ('internal auditorwallace',),
#  ('electrical engineerfox',),
#  ('environmental specialistelliott',),
#  ('help desk technicianmoore',),
#  ('web designer iiimarshall',),
#  ('research associatestevens',),
#  ('media manager ihanson',),
#  ('web designer iiolson',),
#  ('accountant iiiholmes',),
#  ('project managermoore',),
#  ('employees accountant iitorres',),
#  ('financial advisorcarpenter',),
#  ('payment adjustment coordinatorlee',),
#  ('chemical engineerrobertson',),
#  ('administrative officerwhite',),
#  ('director of salesgonzalez',),
#  ('registered nurselittle',),
#  ('employees scientistevans',),
#  ('research nursebanks',),
#  ('product engineerbanks',),
#  ('analog circuit design managerwalker',),
#  ('software test engineer iimarshall',),
#  ('chief design engineercarpenter',),
#  ('librarianreyes',),
#  ('senior editormurphy',),
#  ('accounting assistant iiweaver',),
#  ('financial advisorburton',),
#  ('compensation analystrobertson',),
#  ('chemical engineergardner',),
#  ('employees scientistburke',),
#  ('marketing assistanthudson',),
#  ('accountant ivbell',),
#  ('senior sales associatestewart',),
#  ('professorweaver',),
#  ('payment adjustment coordinatorlane',),
#  ('statistician ivreynolds',),
#  ('vp salesday',),
#  ('software test engineer iigrant',),
#  ('chemical engineerknight',),
#  ('geologist iiimontgomery',),
#  ('help desk operatorrussell',),
#  ('human resources assistant imartinez',),
#  ('structural analysis engineerwoods',),
#  ('biostatistician ivgonzalez',),
#  ('help desk technicianellis',),
#  ('account coordinatormoore',),
#  ('general managerwest',),
#  ('recruiting managerjohnson',),
#  ('occupational therapistrobinson',),
#  ('programmer analyst iiigarrett',),
#  ('biostatistician iwilliams',),
#  ('health coach ithomas',),
#  ('programmer ihawkins',),
#  ('data coordiatorlawrence',),
#  ('employees scientistalexander',),
#  ('systems administrator ihanson',),
#  ('programmer analyst imiller',),
#  ('budget/accounting analyst iiihamilton',),
#  ('automation specialist imoore',),
#  ('payment adjustment coordinatorferguson',),
#  ('systems administrator iiilynch',),
#  ('vp accountingortiz',),
#  ('teacherfisher',),
#  ('account coordinatorramirez',),
#  ('assistant managerwright',),
#  ('internal auditorwashington',),
#  ('marketing assistantgilbert',),
#  ('paralegalstone',),
#  ('administrative officeraustin',),
#  ('payment adjustment coordinatorjacobs',),
#  ('statistician ivgarza',),
#  ('occupational therapistkelley',),
#  ('structural analysis engineerking',),
#  ('occupational therapistmendoza',),
#  ('account executivestanley',),
#  ('developer iiiburns',),
#  ('professorfoster',),
#  ('cost accountantford',),
#  ('electrical engineerspencer',),
#  ('executive secretaryhanson',),
#  ('cost accountantphillips',),
#  ('computer systems analyst iicooper',),
#  ('health coach ihunt',),
#  ('safety technician ivstevens',),
#  ('senior sales associateturner',),
#  ('community outreach specialistjacobs',),
#  ('nuclear power engineertorres',),
#  ('information systems managerbaker',),
#  ('database administrator iiijordan',),
#  ('marketing assistantmedina',),
#  ('nursewilliams',),
#  ('research assistant ivthomas',),
#  ('vp quality controlwilliams',),
#  ('vp salesrivera',),
#  ('recruiting managernichols',),
#  ('systems administrator iiimartinez',),
#  ('vp accountingwilliamson',),
#  ('senior developerharrison',),
#  ('engineer ivmorales',),
#  ('chemical engineergraham',),
#  ('occupational therapiststevens',),
#  ('vp marketingross',),
#  ('employees accountant ivspencer',),
#  ('librarianlong',),
#  ('general managersmith',),
#  ('office assistant iigarza',),
#  ('research associategriffin',),
#  ('registered nursepeterson',),
#  ('database administrator iiiparker',),
#  ('senior developercarroll',),
#  ('occupational therapistwebb',),
#  ('gis technical architectmatthews',),
#  ('vp quality controlbowman',),
#  ('software consultantwalker',),
#  ('web developer iiisnyder',),
#  ('chemical engineersimmons',),
#  ('assistant media plannertorres',),
#  ('executive secretaryanderson',),
#  ('speech pathologisthernandez',),
#  ('statistician iicooper',),
#  ('human resources managerhenry',),
#  ('automation specialist ievans',),
#  ('programmer analyst iiiburton',),
#  ('database administrator icox',),
#  ('professorkelly',),
#  ('electrical engineermills',),
#  ('accountant iiiturner',),
#  ('senior financial analystcox',),
#  ('senior developervasquez',),
#  ('nursejackson',),
#  ('vp product managementfranklin',),
#  ('pharmacistbutler',),
#  ('accountant iijames',),
#  ('account coordinatorwalker',),
#  ('nurse practicionerkelly',),
#  ('nursewilliamson',),
#  ('vp accountingwatkins',),
#  ('office assistant ivcooper',),
#  ('business systems development analystgriffin',),
#  ('desktop support technicianchavez',),
#  ('software test engineer irobertson',),
#  ('vp accountingreynolds',),
#  ('social workershaw',),
#  ('financial analystwhite',),
#  ('account representative iiibennett',),
#  ('librarianortiz',),
#  ('dental hygienistclark',),
#  ('environmental specialisthunter',),
#  ('engineer ivcunningham',),
#  ('assistant media plannergilbert',),
#  ('compensation analystcrawford',),
#  ('senior quality engineerrice',),
#  ('registered nurseburke',),
#  ('registered nursereed',),
#  ('research nurseparker',),
#  ('technical writergutierrez',),
#  ('account representative icarter',),
#  ('senior developermeyer',),
#  ('database administrator ibarnes',),
#  ('senior editorlopez',),
#  ('assistant media plannerruiz',),
#  ('accountant iilopez',),
#  ('account executivescott',),
#  ('actuarycarr',),
#  ('health coach icook',),
#  ('vp quality controlstone',),
#  ('systems administrator ivasquez',),
#  ('software consultantclark',),
#  ('general managerwillis',),
#  ('compensation analysthansen',),
#  ('technical writerkim',),
#  ('community outreach specialistburton',),
#  ('senior editorross',),
#  ('vp marketingperry',),
#  ('product engineerreyes',),
#  ('recruiting managerphillips',),
#  ('geological engineerhansen',),
#  ('accounting assistant ivreyes',),
#  ('mechanical systems engineercunningham',),
#  ('nurse practicionerramos',),
#  ('media manager iiifowler',),
#  ('software engineer iiiellis',),
#  ('mechanical systems engineeryoung',),
#  ('senior sales associatemills',),
#  ('financial analystadams',),
#  ('nuclear power engineersims',),
#  ('executive secretarychavez',),
#  ('biostatistician ivdaniels',),
#  ('editorrose',),
#  ('internal auditormoreno',),
#  ('director of salesgilbert',),
#  ('recruiting managersnyder',),
#  ('account executivelawrence',),
#  ('biostatistician iiibowman',),
#  ('accountant iiicarter',),
#  ('speech pathologistmyers',),
#  ('structural analysis engineertucker',),
#  ('sales associatestephens',),
#  ('analyst programmerburke',),
#  ('recruitermoreno',),
#  ('data coordiatorrice',),
#  ('programmer ivnelson',),
#  ('vp salesjenkins',),
#  ('web developer ivpeters',),
#  ('human resources assistant ipeters',),
#  ('senior sales associatepierce',),
#  ('business systems development analystallen',),
#  ('employees scientistprice',),
#  ('research nursestephens',),
#  ('vp product managementwatkins',),
#  ('compensation analystcarroll',),
#  ('quality engineerfrazier',),
#  ('chief design engineerchavez',),
#  ('assistant media plannerfox',),
#  ('sales representativegonzalez',),
#  ('speech pathologistcollins',),
#  ('gis technical architectmorris',),
#  ('help desk operatorgarcia',),
#  ('senior financial analystrice',),
#  ('director of salesstanley',),
#  ('software test engineer ivgeorge',),
#  ('employees scientistdixon',),
#  ('gis technical architectpayne',),
#  ('project managerwhite',),
#  ('dental hygienistturner',),
#  ('social workeredwards',),
#  ('biostatistician iiiaustin',),
#  ('registered nursegarcia',),
#  ('tax accountantwebb',),
#  ('statistician ivmatthews',),
#  ('web developer iiidiaz',),
#  ('senior cost accountantcruz',),
#  ('accounting assistant isullivan',),
#  ('web designer iiipowell',),
#  ('registered nursegonzalez',),
#  ('operatorrobinson',),
#  ('gis technical architectfuller',),
#  ('automation specialist igeorge',),
#  ('quality engineermurray',),
#  ('clinical specialistcastillo',),
#  ('librarianlynch',),
#  ('civil engineerryan',),
#  ('nuclear power engineerharrison',),
#  ('executive secretarybrooks',),
#  ('clinical specialistdixon',),
#  ('chemical engineerellis',),
#  ('business systems development analystkennedy',),
#  ('geologist ivgonzalez',),
#  ('internal auditorjohnston',),
#  ('physical therapy assistantedwards',),
#  ('vp quality controlmartinez',),
#  ('office assistant iilopez',),
#  ('accountant ivgarza',),
#  ('vp marketinghicks',),
#  ('software test engineer ivfowler',),
#  ('account representative iimills',),
#  ('web designer iihayes',),
#  ('administrative officerfreeman',),
#  ('research assistant iiigarcia',),
#  ('operatorthomas',),
#  ('account coordinatorarmstrong',),
#  ('research assistant iismith',),
#  ('recruiting managerprice',),
#  ('help desk technicianramos',),
#  ('software test engineer ivfoster',),
#  ('financial analystgonzalez',),
#  ('research associateparker',),
#  ('cost accountantrichardson',),
#  ('information systems managerclark',),
#  ('accountant iihanson',),
#  ('civil engineerjenkins',),
#  ('engineer iiihayes',),
#  ('desktop support technicianhamilton',),
#  ('geologist iinguyen',),
#  ('dental hygienistporter',),
#  ('executive secretaryowens',),
#  ('quality engineercruz',),
#  ('editorcrawford',),
#  ('programmer iiiwashington',),
#  ('junior executivegilbert',),
#  ('research assistant ivmontgomery',),
#  ('safety technician ivcarroll',),
#  ('environmental specialistanderson',),
#  ('nurse practicionerandrews',),
#  ('senior financial analystboyd',),
#  ('registered nursediaz',),
#  ('director of salesgutierrez',),
#  ('operatorfreeman',),
#  ('vp quality controlmurphy',),
#  ('engineer iiisanders',),
#  ('health coach iigibson',),
#  ('software engineer ivcrawford',),
#  ('food chemistcampbell',),
#  ('vp accountingellis',),
#  ('financial advisormoreno',),
#  ('mechanical systems engineergonzales',),
#  ('teacheraustin',),
#  ('vp quality controlharper',),
#  ('nursepayne',),
#  ('quality engineercooper',),
#  ('food chemistchapman',),
#  ('analog circuit design managerwilliams',),
#  ('vp product managementmorales',),
#  ('internal auditorberry',),
#  ('developer ivbrooks',),
#  ('sales associatecox',),
#  ('food chemisthudson',),
#  ('help desk operatormorris',),
#  ('human resources assistant iiiwalker',),
#  ('assistant professormyers',),
#  ('geologist ivday',),
#  ('compensation analystolson',),
#  ('financial advisorevans',),
#  ('senior quality engineerbutler',),
#  ('recruitercruz',),
#  ('cost accountantmendoza',),
#  ('research nursewelch',),
#  ('vp accountingferguson',),
#  ('community outreach specialistdiaz',),
#  ('food chemistgonzales',),
#  ('quality control specialistburke',),
#  ('accountant ivmurray',),
#  ('health coach icarpenter',),
#  ('environmental specialistjones',),
#  ('editorsanchez',),
#  ('software consultantbryant',),
#  ('compensation analystgeorge',),
#  ('occupational therapistwells',),
#  ('recruiterburton',),
#  ('analyst programmerhayes',),
#  ('financial analystgutierrez',),
#  ('safety technician ivmeyer',),
#  ('legal assistantgomez',),
#  ('financial analyststanley',),
#  ('dental hygienistsanders',),
#  ('geological engineerford',),
#  ('product engineerellis',),
#  ('senior cost accountantsanders',),
#  ('administrative officerdunn',),
#  ('data coordiatorgarza',),
#  ('vp accountingmills',),
#  ('research nursejacobs',),
#  ('help desk operatorhudson',),
#  ('compensation analystturner',),
#  ('web developer imorgan',),
#  ('gis technical architectpowell',),
#  ('editorwatson',),
#  ('executive secretaryperry',),
#  ('analog circuit design managersullivan',),
#  ('actuaryrodriguez',),
#  ('employees scientistweaver',),
#  ('sales representativemedina',),
#  ('structural engineerowens',),
#  ('automation specialist ivcastillo',),
#  ('cost accountantmoreno',),
#  ('web designer iichapman',),
#  ('assistant professorparker',),
#  ('senior editorwheeler',),
#  ('developer iiiperry',),
#  ('senior quality engineerelliott',),
#  ('payment adjustment coordinatorbaker',),
#  ('business systems development analysttucker',),
#  ('sales associatesims',),
#  ('engineer ivmccoy',),
#  ('operatorgibson',),
#  ('editormurray',),
#  ('graphic designerwilliamson',),
#  ('environmental specialistmoore',),
#  ('senior quality engineerlee',),
#  ('product engineeraustin',),
#  ('research associatekelly',),
#  ('graphic designerkennedy',),
#  ('desktop support technicianmurray',),
#  ('sales associatejames',),
#  ('community outreach specialistjacobs',),
#  ('senior developerchapman',),
#  ('pharmacisthart',),
#  ('editorburns',),
#  ('general managerhoward',),
#  ('programmer iitucker',),
#  ('tax accountantduncan',),
#  ('environmental specialistburke',),
#  ('social workercastillo',),
#  ('software consultanthudson',),
#  ('developer ivsims',),
#  ('vp accountinghicks',),
#  ('web developer ivasquez',),
#  ('vp accountingwalker',),
#  ('registered nursemurphy',),
#  ('programmer analyst iiibishop',),
#  ('research associatecole',),
#  ('environmental specialistross',),
#  ('compensation analystmoore',),
#  ('electrical engineerflores',),
#  ('senior editorfox',),
#  ('geologist iiipierce',),
#  ('research associateramirez',),
#  ('account representative iford',),
#  ('analyst programmerwebb',),
#  ('compensation analystdiaz',),
#  ('senior editorwatkins',),
#  ('geologist ivwashington',),
#  ('computer systems analyst ivjohnston',),
#  ('senior quality engineerrivera',),
#  ('senior sales associatehall',),
#  ('developer iiwilliams',),
#  ('senior developertorres',),
#  ('dental hygienistrice',),
#  ('graphic designerbanks',),
#  ('accountant iparker',),
#  ('professorharrison',),
#  ('compensation analysthayes',),
#  ('business systems development analystriley',),
#  ('clinical specialistcole',),
#  ('clinical specialistmoreno',),
#  ('employees accountant iiilee',),
#  ('employees scientistwilliams',),
#  ('pharmacistwood',),
#  ('programmer ivmorgan',),
#  ('design engineersnyder',),
#  ('structural engineerhughes',),
#  ('accountant ifreeman',),
#  ('product engineergardner',),
#  ('technical writerhicks',),
#  ('associate professorfowler',),
#  ('compensation analystpeterson',),
#  ('marketing managerwebb',),
#  ('pharmacistmiller',),
#  ('social workerlynch',),
#  ('food chemistbennett',),
#  ('legal assistantchavez',),
#  ('employees scientistedwards',),
#  ('design engineerfreeman',),
#  ('paralegalrivera',),
#  ('safety technician ivharper',),
#  ('web developer iikelly',),
#  ('paralegalhayes',),
#  ('occupational therapistgraham',),
#  ('occupational therapisthicks',),
#  ('help desk operatoraustin',),
#  ('desktop support technicianyoung',),
#  ('business systems development analystfox',),
#  ('speech pathologistcastillo',),
#  ('health coach ivlynch',),
#  ('environmental specialistfrazier',),
#  ('programmer ireynolds',),
#  ('structural analysis engineerlong',),
#  ('junior executivecarroll',),
#  ('dental hygienistkelly',),
#  ('accounting assistant iisullivan',),
#  ('vp quality controlwashington',),
#  ('senior quality engineerkelley',),
#  ('information systems managerhall',),
#  ('operatoryoung',),
#  ('accounting assistant ivjames',),
#  ('business systems development analystthomas',),
#  ('sales representativesanchez',),
#  ('vp quality controlcarr',),
#  ('assistant managergreene',),
#  ('assistant media plannerreed',),
#  ('developer iiisimmons',),
#  ('vp quality controlfranklin',),
#  ('legal assistantmorris',),
#  ('senior developermartin',),
#  ('nursedean',),
#  ('account executivethompson',),
#  ('employees accountant iiisanders',),
#  ('tax accountantsanders',),
#  ('geologist iharris',),
#  ('software consultantgeorge',),
#  ('statistician iiharris',),
#  ('clinical specialistgonzales',),
#  ('account coordinatorsnyder',),
#  ('account coordinatorgordon',),
#  ('human resources assistant iiicooper',),
#  ('senior editorspencer',),
#  ('electrical engineerroberts',),
#  ('research assistant ilittle',),
#  ('nurse practicionergriffin',),
#  ('senior financial analystkelley',),
#  ('account representative iarnold',),
#  ('electrical engineerwarren',),
#  ('vp accountingclark',),
#  ('account representative ijohnson',),
#  ('senior financial analystelliott',),
#  ('software engineer iiweaver',),
#  ('biostatistician iigomez',),
#  ('help desk operatorknight',),
#  ('data coordiatorrice',),
#  ('analyst programmerprice',),
#  ('mechanical systems engineerbishop',),
#  ('assistant managerwalker',),
#  ('statistician iknight',),
#  ('editorlittle',),
#  ('vp quality controlhamilton',),
#  ('senior cost accountanthunt',),
#  ('civil engineerhernandez',),
#  ('compensation analystroberts',),
#  ('social workerfoster',),
#  ('budget/accounting analyst iiarmstrong',),
#  ('health coach ibanks',),
#  ('accounting assistant iholmes',),
#  ('programmer analyst iperez',),
#  ('software test engineer iwelch',),
#  ('senior editorkelley',),
#  ('research associatesullivan',),
#  ('assistant managerharper',),
#  ('data coordiatorbryant',),
#  ('research associaterobinson',),
#  ('nuclear power engineerbrooks',),
#  ('geologist ivbailey',),
#  ('compensation analystharrison',),
#  ('nursemendoza',),
#  ('assistant professorrice',),
#  ('web developer iiicruz',),
#  ('chief design engineercook',),
#  ('human resources managerwillis',),
#  ('programmer ivsullivan',),
#  ('senior quality engineermills',),
#  ('web developer iperkins',),
#  ('chemical engineermills',),
#  ('vp salesward',),
#  ('accountant iiijacobs',),
#  ('information systems managermiller',),
#  ('help desk technicianchavez',),
#  ('registered nursegrant',),
#  ('analog circuit design managerhoward',),
#  ('statistician ivyoung',),
#  ('registered nursefields',),
#  ('payment adjustment coordinatorbradley',),
#  ('junior executivelawrence',),
#  ('geologist iiallen',),
#  ('financial advisorlane',),
#  ('senior financial analystsanchez',),
#  ('accounting assistant iiiwelch',),
#  ('systems administrator iimartinez',),
#  ('vp quality controlharper',),
#  ('vp marketingharvey',),
#  ('legal assistantlopez',),
#  ('administrative assistant iiwilliamson',),
#  ('systems administrator iigordon',),
#  ('geological engineerjacobs',),
#  ('internal auditormatthews',),
#  ('paralegalellis',),
#  ('programmer iiiwashington',),
#  ('design engineerruiz',),
#  ('safety technician icunningham',),
#  ('junior executivefowler',),
#  ('compensation analysthudson',),
#  ('senior financial analystreynolds',),
#  ('project managerparker',),
#  ('administrative assistant ivharvey',),
#  ('nursejenkins',),
#  ('senior editorlawrence',),
#  ('research nursecarpenter',),
#  ('executive secretarybryant',),
#  ('occupational therapistwatkins',),
#  ('database administrator iiruiz',),
#  ('chemical engineerandrews',),
#  ('actuarypierce',),
#  ('employees scientistfowler',),
#  ('quality control specialistramos',),
#  ('employees accountant iiilynch',),
#  ('employees accountant iigreene',),
#  ('research associatelarson',),
#  ('pharmacistreed',),
#  ('research assistant iilarson',),
#  ('web developer ipeterson',),
#  ('electrical engineerrodriguez',),
#  ('web designer ihall',),
#  ('assistant professorhoward',),
#  ('marketing assistantwebb',),
#  ('budget/accounting analyst iiicollins',),
#  ('health coach ivburns',),
#  ('account representative ivphillips',),
#  ('help desk operatordunn',),
#  ('director of salesedwards',),
#  ('quality control specialistyoung',),
#  ('associate professorburton',),
#  ('research nursekelley',),
#  ('account representative iiihenry',),
#  ('accountant imeyer',),
#  ('social workerreed',),
#  ('assistant professorharrison',),
#  ('technical writerpeterson',),
#  ('accountant iiwalker',),
#  ('executive secretaryharrison',),
#  ('marketing managerlane',),
#  ('administrative assistant iiimccoy',),
#  ('business systems development analystcarroll',),
#  ('marketing managerbrooks',),
#  ('civil engineerfreeman',),
#  ('developer ivwatson',),
#  ('software engineer iihunter',),
#  ('sales associateduncan',),
#  ('safety technician iford',),
#  ('teacherfreeman',),
#  ('senior cost accountantknight',),
#  ('financial advisorporter',),
#  ('recruiting managerrussell',),
#  ('pharmacistnelson',),
#  ('database administrator iarnold',),
#  ('senior quality engineermoreno',),
#  ('senior cost accountantfuller',),
#  ('nurse practicionerowens',),
#  ('research associateparker',),
#  ('graphic designerrichards',),
#  ('vp product managementhill',),
#  ('environmental techaustin',),
#  ('statistician irose',),
#  ('desktop support technicianturner',),
#  ('recruiting managermontgomery',),
#  ('engineer igeorge',),
#  ('chemical engineerburton',),
#  ('mechanical systems engineerwright',),
#  ('senior sales associatelopez',),
#  ('senior editorkelly',),
#  ('programmer analyst ivwoods',),
#  ('professorkennedy',),
#  ('editorcole',),
#  ('financial advisorarmstrong',),
#  ('account representative iiiferguson',),
#  ('director of salespalmer',),
#  ('registered nursebell',),
#  ('technical writerelliott',),
#  ('quality control specialistsimmons',),
#  ('librarianbutler',),
#  ('employees accountant ihanson',),
#  ('help desk technicianalvarez',),
#  ('senior sales associatejordan',),
#  ('product engineerriley',),
#  ('vp marketingpeters',),
#  ('food chemisthudson',),
#  ('pharmacistgilbert',),
#  ('human resources assistant iiimurray',),
#  ('operatorsims',),
#  ('systems administrator iiiclark',),
#  ('teacherschmidt',),
#  ('registered nursehall',),
#  ('software engineer iford',),
#  ('systems administrator imason',),
#  ('product engineercole',),
#  ('recruiterrodriguez',),
#  ('senior cost accountantkennedy',),
#  ('gis technical architectcunningham',),
#  ('community outreach specialistdiaz',),
#  ('nuclear power engineerreyes',),
#  ('gis technical architectmeyer',),
#  ('budget/accounting analyst iiwatkins',),
#  ('biostatistician iiifowler',),
#  ('structural analysis engineerwells',),
#  ('project managerhicks',),
#  ('help desk operatorjohnston',),
#  ('design engineernguyen',),
#  ('health coach ivphillips',),
#  ('structural engineeranderson',),
#  ('structural analysis engineerdixon',),
#  ('paralegalkelly',),
#  ('tax accountanthawkins',),
#  ('research nurselopez',),
#  ('executive secretaryphillips',),
#  ('accountant iwillis',),
#  ('occupational therapistwatson',),
#  ('environmental specialistdaniels',),
#  ('accounting assistant igomez',),
#  ('database administrator igutierrez',),
#  ('analog circuit design managerharvey',),
#  ('teacherthomas',),
#  ('structural engineerjohnston',),
#  ('geological engineerjenkins',),
#  ('associate professorfrazier',),
#  ('senior financial analystharris',),
#  ('civil engineerhenry',),
#  ('accountant ibishop',),
#  ('assistant media plannerferguson',),
#  ('database administrator iimason',),
#  ('vp quality controlpayne',),
#  ('librarianperez',),
#  ('software consultantday',),
#  ('teacherhenderson',),
#  ('research nursecole',),
#  ('project managerperez',),
#  ('systems administrator ivrodriguez',),
#  ('geological engineerwebb',),
#  ('nuclear power engineerwilliams',),
#  ('vp product managementdixon',),
#  ('gis technical architectgonzalez',),
#  ('budget/accounting analyst iiiwilliamson',),
#  ('account coordinatorallen',),
#  ('vp quality controlhanson',),
#  ('registered nursehill',),
#  ('social workerwright',),
#  ('cost accountantroberts',),
#  ('assistant managerfrazier',),
#  ('senior sales associatebell',),
#  ('account representative ivcole',),
#  ('programmer analyst ivjames',),
#  ('compensation analystwood',),
#  ('civil engineerlawrence',),
#  ('safety technician iharris',),
#  ('business systems development analyststephens',),
#  ('vp marketingreed',),
#  ('data coordiatorstewart',),
#  ('chemical engineerevans',),
#  ('human resources assistant ivmeyer',),
#  ('technical writerlarson',),
#  ('professorwagner',),
#  ('sales representativeriley',),
#  ('geological engineerromero',),
#  ('payment adjustment coordinatorlong',),
#  ('product engineermartin',),
#  ('geological engineerfoster',),
#  ('analog circuit design managerholmes',),
#  ('geologist iiigreene',),
#  ('senior quality engineerkennedy',),
#  ('budget/accounting analyst iiiharris',),
#  ('environmental techstevens',),
#  ('office assistant iiihansen',),
#  ('systems administrator ivstanley',),
#  ('desktop support techniciansimpson',),
#  ('engineer ifrazier',),
#  ('general managermartin',),
#  ('chemical engineerramirez',),
#  ('graphic designerowens',),
#  ('payment adjustment coordinatoradams',),
#  ('business systems development analystwatkins',),
#  ('systems administrator iray',),
#  ('editorphillips',),
#  ('graphic designerbaker',),
#  ('electrical engineerblack',),
#  ('help desk operatornichols',),
#  ('environmental specialistalexander',),
#  ('research assistant iiiwallace',),
#  ('database administrator ijordan',),
#  ('account executiveaustin',),
#  ('recruiting managerburton',),
#  ('social workermorrison',),
#  ('social workerlewis',),
#  ('research nursewelch',),
#  ('assistant media plannermendoza',),
#  ('sales representativescott',),
#  ...]

# %%
engine.execute("select job_title || '-' || null from employees limit 10;").fetchall()
# Out:
# [(None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,),
#  (None,)]

# %%
engine.execute("select concat(job_title, '-', null) from employees;").fetchall()
# Out:
# [('structural engineer-',),
#  ('marketing assistant-',),
#  ('recruiting manager-',),
#  ('electrical engineer-',),
#  ('senior editor-',),
#  ('environmental tech-',),
#  ('senior editor-',),
#  ('tax accountant-',),
#  ('senior editor-',),
#  ('structural engineer-',),
#  ('assistant manager-',),
#  ('administrative officer-',),
#  ('analyst programmer-',),
#  ('vp product management-',),
#  ('software consultant-',),
#  ('environmental tech-',),
#  ('programmer iv-',),
#  ('desktop support technician-',),
#  ('marketing assistant-',),
#  ('community outreach specialist-',),
#  ('cost accountant-',),
#  ('office assistant iii-',),
#  ('computer systems analyst i-',),
#  ('product engineer-',),
#  ('assistant professor-',),
#  ('associate professor-',),
#  ('electrical engineer-',),
#  ('vp sales-',),
#  ('recruiting manager-',),
#  ('community outreach specialist-',),
#  ('administrative assistant iii-',),
#  ('software test engineer i-',),
#  ('biostatistician i-',),
#  ('developer i-',),
#  ('programmer iv-',),
#  ('graphic designer-',),
#  ('human resources assistant ii-',),
#  ('technical writer-',),
#  ('technical writer-',),
#  ('media manager ii-',),
#  ('nurse-',),
#  ('sales associate-',),
#  ('graphic designer-',),
#  ('gis technical architect-',),
#  ('research assistant ii-',),
#  ('pharmacist-',),
#  ('vp product management-',),
#  ('recruiting manager-',),
#  ('marketing assistant-',),
#  ('electrical engineer-',),
#  ('senior editor-',),
#  ('environmental tech-',),
#  ('senior editor-',),
#  ('tax accountant-',),
#  ('senior editor-',),
#  ('structural engineer-',),
#  ('assistant manager-',),
#  ('administrative officer-',),
#  ('analyst programmer-',),
#  ('vp product management-',),
#  ('software consultant-',),
#  ('environmental tech-',),
#  ('programmer iv-',),
#  ('desktop support technician-',),
#  ('marketing assistant-',),
#  ('community outreach specialist-',),
#  ('cost accountant-',),
#  ('office assistant iii-',),
#  ('computer systems analyst i-',),
#  ('product engineer-',),
#  ('assistant professor-',),
#  ('associate professor-',),
#  ('electrical engineer-',),
#  ('vp sales-',),
#  ('recruiting manager-',),
#  ('community outreach specialist-',),
#  ('administrative assistant iii-',),
#  ('software test engineer i-',),
#  ('biostatistician i-',),
#  ('developer i-',),
#  ('programmer iv-',),
#  ('graphic designer-',),
#  ('human resources assistant ii-',),
#  ('technical writer-',),
#  ('technical writer-',),
#  ('media manager ii-',),
#  ('nurse-',),
#  ('sales associate-',),
#  ('graphic designer-',),
#  ('gis technical architect-',),
#  ('research assistant ii-',),
#  ('pharmacist-',),
#  ('vp product management-',),
#  ('compensation analyst-',),
#  ('web developer iii-',),
#  ('civil engineer-',),
#  ('web developer iii-',),
#  ('senior developer-',),
#  ('operator-',),
#  ('registered nurse-',),
#  ('operator-',),
#  ('librarian-',),
#  ('clinical specialist-',),
#  ('junior executive-',),
#  ('data coordiator-',),
#  ('tax accountant-',),
#  ('programmer iv-',),
#  ('marketing assistant-',),
#  ('sales representative-',),
#  ('analog circuit design manager-',),
#  ('graphic designer-',),
#  ('database administrator iii-',),
#  ('accounting assistant iii-',),
#  ('occupational therapist-',),
#  ('assistant media planner-',),
#  ('nurse practicioner-',),
#  ('programmer iii-',),
#  ('software test engineer i-',),
#  ('administrative officer-',),
#  ('senior editor-',),
#  ('analyst programmer-',),
#  ('senior quality engineer-',),
#  ('assistant professor-',),
#  ('general manager-',),
#  ('business systems development analyst-',),
#  ('structural analysis engineer-',),
#  ('accountant ii-',),
#  ('chief design engineer-',),
#  ('nurse practicioner-',),
#  ('analyst programmer-',),
#  ('account executive-',),
#  ('design engineer-',),
#  ('design engineer-',),
#  ('web developer iv-',),
#  ('structural engineer-',),
#  ('senior financial analyst-',),
#  ('quality control specialist-',),
#  ('general manager-',),
#  ('account representative iii-',),
#  ('product engineer-',),
#  ('web developer i-',),
#  ('accounting assistant i-',),
#  ('accountant iv-',),
#  ('office assistant iv-',),
#  ('tax accountant-',),
#  ('accounting assistant iv-',),
#  ('business systems development analyst-',),
#  ('associate professor-',),
#  ('paralegal-',),
#  ('computer systems analyst iii-',),
#  ('structural engineer-',),
#  ('database administrator ii-',),
#  ('employees accountant iii-',),
#  ('food chemist-',),
#  ('technical writer-',),
#  ('senior developer-',),
#  ('quality control specialist-',),
#  ('community outreach specialist-',),
#  ('financial advisor-',),
#  ('electrical engineer-',),
#  ('teacher-',),
#  ('teacher-',),
#  ('registered nurse-',),
#  ('executive secretary-',),
#  ('office assistant iv-',),
#  ('clinical specialist-',),
#  ('assistant media planner-',),
#  ('operator-',),
#  ('analyst programmer-',),
#  ('computer systems analyst i-',),
#  ('sales representative-',),
#  ('electrical engineer-',),
#  ('web designer ii-',),
#  ('help desk operator-',),
#  ('quality engineer-',),
#  ('social worker-',),
#  ('account representative iv-',),
#  ('marketing manager-',),
#  ('database administrator iv-',),
#  ('design engineer-',),
#  ('vp product management-',),
#  ('paralegal-',),
#  ('computer systems analyst iv-',),
#  ('systems administrator ii-',),
#  ('mechanical systems engineer-',),
#  ('speech pathologist-',),
#  ('legal assistant-',),
#  ('accountant iv-',),
#  ('environmental tech-',),
#  ('librarian-',),
#  ('accountant iii-',),
#  ('data coordiator-',),
#  ('quality engineer-',),
#  ('quality engineer-',),
#  ('software engineer iii-',),
#  ('junior executive-',),
#  ('senior cost accountant-',),
#  ('general manager-',),
#  ('graphic designer-',),
#  ('speech pathologist-',),
#  ('financial advisor-',),
#  ('compensation analyst-',),
#  ('health coach iii-',),
#  ('sales associate-',),
#  ('web developer ii-',),
#  ('engineer iii-',),
#  ('research assistant i-',),
#  ('vp product management-',),
#  ('nuclear power engineer-',),
#  ('computer systems analyst i-',),
#  ('help desk technician-',),
#  ('systems administrator iv-',),
#  ('vp quality control-',),
#  ('recruiter-',),
#  ('structural analysis engineer-',),
#  ('senior editor-',),
#  ('biostatistician i-',),
#  ('human resources assistant i-',),
#  ('director of sales-',),
#  ('senior developer-',),
#  ('administrative officer-',),
#  ('software engineer i-',),
#  ('assistant media planner-',),
#  ('technical writer-',),
#  ('research assistant iii-',),
#  ('marketing assistant-',),
#  ('sales representative-',),
#  ('sales representative-',),
#  ('vp accounting-',),
#  ('geological engineer-',),
#  ('information systems manager-',),
#  ('senior cost accountant-',),
#  ('legal assistant-',),
#  ('administrative assistant i-',),
#  ('office assistant iii-',),
#  ('structural analysis engineer-',),
#  ('actuary-',),
#  ('operator-',),
#  ('help desk operator-',),
#  ('marketing assistant-',),
#  ('cost accountant-',),
#  ('vp product management-',),
#  ('teacher-',),
#  ('media manager i-',),
#  ('dental hygienist-',),
#  ('software test engineer iii-',),
#  ('executive secretary-',),
#  ('financial advisor-',),
#  ('automation specialist i-',),
#  ('civil engineer-',),
#  ('help desk operator-',),
#  ('engineer ii-',),
#  ('nurse-',),
#  ('information systems manager-',),
#  ('automation specialist i-',),
#  ('electrical engineer-',),
#  ('human resources assistant ii-',),
#  ('software engineer iii-',),
#  ('computer systems analyst i-',),
#  ('internal auditor-',),
#  ('electrical engineer-',),
#  ('environmental specialist-',),
#  ('help desk technician-',),
#  ('web designer iii-',),
#  ('research associate-',),
#  ('media manager i-',),
#  ('web designer ii-',),
#  ('accountant iii-',),
#  ('project manager-',),
#  ('employees accountant ii-',),
#  ('financial advisor-',),
#  ('payment adjustment coordinator-',),
#  ('chemical engineer-',),
#  ('administrative officer-',),
#  ('director of sales-',),
#  ('registered nurse-',),
#  ('employees scientist-',),
#  ('research nurse-',),
#  ('product engineer-',),
#  ('analog circuit design manager-',),
#  ('software test engineer ii-',),
#  ('chief design engineer-',),
#  ('librarian-',),
#  ('senior editor-',),
#  ('accounting assistant ii-',),
#  ('financial advisor-',),
#  ('compensation analyst-',),
#  ('chemical engineer-',),
#  ('employees scientist-',),
#  ('marketing assistant-',),
#  ('accountant iv-',),
#  ('senior sales associate-',),
#  ('professor-',),
#  ('payment adjustment coordinator-',),
#  ('statistician iv-',),
#  ('vp sales-',),
#  ('software test engineer ii-',),
#  ('chemical engineer-',),
#  ('geologist iii-',),
#  ('help desk operator-',),
#  ('human resources assistant i-',),
#  ('structural analysis engineer-',),
#  ('biostatistician iv-',),
#  ('help desk technician-',),
#  ('account coordinator-',),
#  ('general manager-',),
#  ('recruiting manager-',),
#  ('occupational therapist-',),
#  ('programmer analyst iii-',),
#  ('biostatistician i-',),
#  ('health coach i-',),
#  ('programmer i-',),
#  ('data coordiator-',),
#  ('employees scientist-',),
#  ('systems administrator i-',),
#  ('programmer analyst i-',),
#  ('budget/accounting analyst iii-',),
#  ('automation specialist i-',),
#  ('payment adjustment coordinator-',),
#  ('systems administrator iii-',),
#  ('vp accounting-',),
#  ('teacher-',),
#  ('account coordinator-',),
#  ('assistant manager-',),
#  ('internal auditor-',),
#  ('marketing assistant-',),
#  ('paralegal-',),
#  ('administrative officer-',),
#  ('payment adjustment coordinator-',),
#  ('statistician iv-',),
#  ('occupational therapist-',),
#  ('structural analysis engineer-',),
#  ('occupational therapist-',),
#  ('account executive-',),
#  ('developer iii-',),
#  ('professor-',),
#  ('cost accountant-',),
#  ('electrical engineer-',),
#  ('executive secretary-',),
#  ('cost accountant-',),
#  ('computer systems analyst ii-',),
#  ('health coach i-',),
#  ('safety technician iv-',),
#  ('senior sales associate-',),
#  ('community outreach specialist-',),
#  ('nuclear power engineer-',),
#  ('information systems manager-',),
#  ('database administrator iii-',),
#  ('marketing assistant-',),
#  ('nurse-',),
#  ('research assistant iv-',),
#  ('vp quality control-',),
#  ('vp sales-',),
#  ('recruiting manager-',),
#  ('systems administrator iii-',),
#  ('vp accounting-',),
#  ('senior developer-',),
#  ('engineer iv-',),
#  ('chemical engineer-',),
#  ('occupational therapist-',),
#  ('vp marketing-',),
#  ('employees accountant iv-',),
#  ('librarian-',),
#  ('general manager-',),
#  ('office assistant ii-',),
#  ('research associate-',),
#  ('registered nurse-',),
#  ('database administrator iii-',),
#  ('senior developer-',),
#  ('occupational therapist-',),
#  ('gis technical architect-',),
#  ('vp quality control-',),
#  ('software consultant-',),
#  ('web developer iii-',),
#  ('chemical engineer-',),
#  ('assistant media planner-',),
#  ('executive secretary-',),
#  ('speech pathologist-',),
#  ('statistician ii-',),
#  ('human resources manager-',),
#  ('automation specialist i-',),
#  ('programmer analyst iii-',),
#  ('database administrator i-',),
#  ('professor-',),
#  ('electrical engineer-',),
#  ('accountant iii-',),
#  ('senior financial analyst-',),
#  ('senior developer-',),
#  ('nurse-',),
#  ('vp product management-',),
#  ('pharmacist-',),
#  ('accountant ii-',),
#  ('account coordinator-',),
#  ('nurse practicioner-',),
#  ('nurse-',),
#  ('vp accounting-',),
#  ('office assistant iv-',),
#  ('business systems development analyst-',),
#  ('desktop support technician-',),
#  ('software test engineer i-',),
#  ('vp accounting-',),
#  ('social worker-',),
#  ('financial analyst-',),
#  ('account representative iii-',),
#  ('librarian-',),
#  ('dental hygienist-',),
#  ('environmental specialist-',),
#  ('engineer iv-',),
#  ('assistant media planner-',),
#  ('compensation analyst-',),
#  ('senior quality engineer-',),
#  ('registered nurse-',),
#  ('registered nurse-',),
#  ('research nurse-',),
#  ('technical writer-',),
#  ('account representative i-',),
#  ('senior developer-',),
#  ('database administrator i-',),
#  ('senior editor-',),
#  ('assistant media planner-',),
#  ('accountant ii-',),
#  ('account executive-',),
#  ('actuary-',),
#  ('health coach i-',),
#  ('vp quality control-',),
#  ('systems administrator i-',),
#  ('software consultant-',),
#  ('general manager-',),
#  ('compensation analyst-',),
#  ('technical writer-',),
#  ('community outreach specialist-',),
#  ('senior editor-',),
#  ('vp marketing-',),
#  ('product engineer-',),
#  ('recruiting manager-',),
#  ('geological engineer-',),
#  ('accounting assistant iv-',),
#  ('mechanical systems engineer-',),
#  ('nurse practicioner-',),
#  ('media manager iii-',),
#  ('software engineer iii-',),
#  ('mechanical systems engineer-',),
#  ('senior sales associate-',),
#  ('financial analyst-',),
#  ('nuclear power engineer-',),
#  ('executive secretary-',),
#  ('biostatistician iv-',),
#  ('editor-',),
#  ('internal auditor-',),
#  ('director of sales-',),
#  ('recruiting manager-',),
#  ('account executive-',),
#  ('biostatistician iii-',),
#  ('accountant iii-',),
#  ('speech pathologist-',),
#  ('structural analysis engineer-',),
#  ('sales associate-',),
#  ('analyst programmer-',),
#  ('recruiter-',),
#  ('data coordiator-',),
#  ('programmer iv-',),
#  ('vp sales-',),
#  ('web developer iv-',),
#  ('human resources assistant i-',),
#  ('senior sales associate-',),
#  ('business systems development analyst-',),
#  ('employees scientist-',),
#  ('research nurse-',),
#  ('vp product management-',),
#  ('compensation analyst-',),
#  ('quality engineer-',),
#  ('chief design engineer-',),
#  ('assistant media planner-',),
#  ('sales representative-',),
#  ('speech pathologist-',),
#  ('gis technical architect-',),
#  ('help desk operator-',),
#  ('senior financial analyst-',),
#  ('director of sales-',),
#  ('software test engineer iv-',),
#  ('employees scientist-',),
#  ('gis technical architect-',),
#  ('project manager-',),
#  ('dental hygienist-',),
#  ('social worker-',),
#  ('biostatistician iii-',),
#  ('registered nurse-',),
#  ('tax accountant-',),
#  ('statistician iv-',),
#  ('web developer iii-',),
#  ('senior cost accountant-',),
#  ('accounting assistant i-',),
#  ('web designer iii-',),
#  ('registered nurse-',),
#  ('operator-',),
#  ('gis technical architect-',),
#  ('automation specialist i-',),
#  ('quality engineer-',),
#  ('clinical specialist-',),
#  ('librarian-',),
#  ('civil engineer-',),
#  ('nuclear power engineer-',),
#  ('executive secretary-',),
#  ('clinical specialist-',),
#  ('chemical engineer-',),
#  ('business systems development analyst-',),
#  ('geologist iv-',),
#  ('internal auditor-',),
#  ('physical therapy assistant-',),
#  ('vp quality control-',),
#  ('office assistant ii-',),
#  ('accountant iv-',),
#  ('vp marketing-',),
#  ('software test engineer iv-',),
#  ('account representative ii-',),
#  ('web designer ii-',),
#  ('administrative officer-',),
#  ('research assistant iii-',),
#  ('operator-',),
#  ('account coordinator-',),
#  ('research assistant ii-',),
#  ('recruiting manager-',),
#  ('help desk technician-',),
#  ('software test engineer iv-',),
#  ('financial analyst-',),
#  ('research associate-',),
#  ('cost accountant-',),
#  ('information systems manager-',),
#  ('accountant ii-',),
#  ('civil engineer-',),
#  ('engineer iii-',),
#  ('desktop support technician-',),
#  ('geologist ii-',),
#  ('dental hygienist-',),
#  ('executive secretary-',),
#  ('quality engineer-',),
#  ('editor-',),
#  ('programmer iii-',),
#  ('junior executive-',),
#  ('research assistant iv-',),
#  ('safety technician iv-',),
#  ('environmental specialist-',),
#  ('nurse practicioner-',),
#  ('senior financial analyst-',),
#  ('registered nurse-',),
#  ('director of sales-',),
#  ('operator-',),
#  ('vp quality control-',),
#  ('engineer iii-',),
#  ('health coach ii-',),
#  ('software engineer iv-',),
#  ('food chemist-',),
#  ('vp accounting-',),
#  ('financial advisor-',),
#  ('mechanical systems engineer-',),
#  ('teacher-',),
#  ('vp quality control-',),
#  ('nurse-',),
#  ('quality engineer-',),
#  ('food chemist-',),
#  ('analog circuit design manager-',),
#  ('vp product management-',),
#  ('internal auditor-',),
#  ('developer iv-',),
#  ('sales associate-',),
#  ('food chemist-',),
#  ('help desk operator-',),
#  ('human resources assistant iii-',),
#  ('assistant professor-',),
#  ('geologist iv-',),
#  ('compensation analyst-',),
#  ('financial advisor-',),
#  ('senior quality engineer-',),
#  ('recruiter-',),
#  ('cost accountant-',),
#  ('research nurse-',),
#  ('vp accounting-',),
#  ('community outreach specialist-',),
#  ('food chemist-',),
#  ('quality control specialist-',),
#  ('accountant iv-',),
#  ('health coach i-',),
#  ('environmental specialist-',),
#  ('editor-',),
#  ('software consultant-',),
#  ('compensation analyst-',),
#  ('occupational therapist-',),
#  ('recruiter-',),
#  ('analyst programmer-',),
#  ('financial analyst-',),
#  ('safety technician iv-',),
#  ('legal assistant-',),
#  ('financial analyst-',),
#  ('dental hygienist-',),
#  ('geological engineer-',),
#  ('product engineer-',),
#  ('senior cost accountant-',),
#  ('administrative officer-',),
#  ('data coordiator-',),
#  ('vp accounting-',),
#  ('research nurse-',),
#  ('help desk operator-',),
#  ('compensation analyst-',),
#  ('web developer i-',),
#  ('gis technical architect-',),
#  ('editor-',),
#  ('executive secretary-',),
#  ('analog circuit design manager-',),
#  ('actuary-',),
#  ('employees scientist-',),
#  ('sales representative-',),
#  ('structural engineer-',),
#  ('automation specialist iv-',),
#  ('cost accountant-',),
#  ('web designer ii-',),
#  ('assistant professor-',),
#  ('senior editor-',),
#  ('developer iii-',),
#  ('senior quality engineer-',),
#  ('payment adjustment coordinator-',),
#  ('business systems development analyst-',),
#  ('sales associate-',),
#  ('engineer iv-',),
#  ('operator-',),
#  ('editor-',),
#  ('graphic designer-',),
#  ('environmental specialist-',),
#  ('senior quality engineer-',),
#  ('product engineer-',),
#  ('research associate-',),
#  ('graphic designer-',),
#  ('desktop support technician-',),
#  ('sales associate-',),
#  ('community outreach specialist-',),
#  ('senior developer-',),
#  ('pharmacist-',),
#  ('editor-',),
#  ('general manager-',),
#  ('programmer ii-',),
#  ('tax accountant-',),
#  ('environmental specialist-',),
#  ('social worker-',),
#  ('software consultant-',),
#  ('developer iv-',),
#  ('vp accounting-',),
#  ('web developer i-',),
#  ('vp accounting-',),
#  ('registered nurse-',),
#  ('programmer analyst iii-',),
#  ('research associate-',),
#  ('environmental specialist-',),
#  ('compensation analyst-',),
#  ('electrical engineer-',),
#  ('senior editor-',),
#  ('geologist iii-',),
#  ('research associate-',),
#  ('account representative i-',),
#  ('analyst programmer-',),
#  ('compensation analyst-',),
#  ('senior editor-',),
#  ('geologist iv-',),
#  ('computer systems analyst iv-',),
#  ('senior quality engineer-',),
#  ('senior sales associate-',),
#  ('developer ii-',),
#  ('senior developer-',),
#  ('dental hygienist-',),
#  ('graphic designer-',),
#  ('accountant i-',),
#  ('professor-',),
#  ('compensation analyst-',),
#  ('business systems development analyst-',),
#  ('clinical specialist-',),
#  ('clinical specialist-',),
#  ('employees accountant iii-',),
#  ('employees scientist-',),
#  ('pharmacist-',),
#  ('programmer iv-',),
#  ('design engineer-',),
#  ('structural engineer-',),
#  ('accountant i-',),
#  ('product engineer-',),
#  ('technical writer-',),
#  ('associate professor-',),
#  ('compensation analyst-',),
#  ('marketing manager-',),
#  ('pharmacist-',),
#  ('social worker-',),
#  ('food chemist-',),
#  ('legal assistant-',),
#  ('employees scientist-',),
#  ('design engineer-',),
#  ('paralegal-',),
#  ('safety technician iv-',),
#  ('web developer ii-',),
#  ('paralegal-',),
#  ('occupational therapist-',),
#  ('occupational therapist-',),
#  ('help desk operator-',),
#  ('desktop support technician-',),
#  ('business systems development analyst-',),
#  ('speech pathologist-',),
#  ('health coach iv-',),
#  ('environmental specialist-',),
#  ('programmer i-',),
#  ('structural analysis engineer-',),
#  ('junior executive-',),
#  ('dental hygienist-',),
#  ('accounting assistant ii-',),
#  ('vp quality control-',),
#  ('senior quality engineer-',),
#  ('information systems manager-',),
#  ('operator-',),
#  ('accounting assistant iv-',),
#  ('business systems development analyst-',),
#  ('sales representative-',),
#  ('vp quality control-',),
#  ('assistant manager-',),
#  ('assistant media planner-',),
#  ('developer iii-',),
#  ('vp quality control-',),
#  ('legal assistant-',),
#  ('senior developer-',),
#  ('nurse-',),
#  ('account executive-',),
#  ('employees accountant iii-',),
#  ('tax accountant-',),
#  ('geologist i-',),
#  ('software consultant-',),
#  ('statistician ii-',),
#  ('clinical specialist-',),
#  ('account coordinator-',),
#  ('account coordinator-',),
#  ('human resources assistant iii-',),
#  ('senior editor-',),
#  ('electrical engineer-',),
#  ('research assistant i-',),
#  ('nurse practicioner-',),
#  ('senior financial analyst-',),
#  ('account representative i-',),
#  ('electrical engineer-',),
#  ('vp accounting-',),
#  ('account representative i-',),
#  ('senior financial analyst-',),
#  ('software engineer ii-',),
#  ('biostatistician ii-',),
#  ('help desk operator-',),
#  ('data coordiator-',),
#  ('analyst programmer-',),
#  ('mechanical systems engineer-',),
#  ('assistant manager-',),
#  ('statistician i-',),
#  ('editor-',),
#  ('vp quality control-',),
#  ('senior cost accountant-',),
#  ('civil engineer-',),
#  ('compensation analyst-',),
#  ('social worker-',),
#  ('budget/accounting analyst ii-',),
#  ('health coach i-',),
#  ('accounting assistant i-',),
#  ('programmer analyst i-',),
#  ('software test engineer i-',),
#  ('senior editor-',),
#  ('research associate-',),
#  ('assistant manager-',),
#  ('data coordiator-',),
#  ('research associate-',),
#  ('nuclear power engineer-',),
#  ('geologist iv-',),
#  ('compensation analyst-',),
#  ('nurse-',),
#  ('assistant professor-',),
#  ('web developer iii-',),
#  ('chief design engineer-',),
#  ('human resources manager-',),
#  ('programmer iv-',),
#  ('senior quality engineer-',),
#  ('web developer i-',),
#  ('chemical engineer-',),
#  ('vp sales-',),
#  ('accountant iii-',),
#  ('information systems manager-',),
#  ('help desk technician-',),
#  ('registered nurse-',),
#  ('analog circuit design manager-',),
#  ('statistician iv-',),
#  ('registered nurse-',),
#  ('payment adjustment coordinator-',),
#  ('junior executive-',),
#  ('geologist ii-',),
#  ('financial advisor-',),
#  ('senior financial analyst-',),
#  ('accounting assistant iii-',),
#  ('systems administrator ii-',),
#  ('vp quality control-',),
#  ('vp marketing-',),
#  ('legal assistant-',),
#  ('administrative assistant ii-',),
#  ('systems administrator ii-',),
#  ('geological engineer-',),
#  ('internal auditor-',),
#  ('paralegal-',),
#  ('programmer iii-',),
#  ('design engineer-',),
#  ('safety technician i-',),
#  ('junior executive-',),
#  ('compensation analyst-',),
#  ('senior financial analyst-',),
#  ('project manager-',),
#  ('administrative assistant iv-',),
#  ('nurse-',),
#  ('senior editor-',),
#  ('research nurse-',),
#  ('executive secretary-',),
#  ('occupational therapist-',),
#  ('database administrator ii-',),
#  ('chemical engineer-',),
#  ('actuary-',),
#  ('employees scientist-',),
#  ('quality control specialist-',),
#  ('employees accountant iii-',),
#  ('employees accountant ii-',),
#  ('research associate-',),
#  ('pharmacist-',),
#  ('research assistant ii-',),
#  ('web developer i-',),
#  ('electrical engineer-',),
#  ('web designer i-',),
#  ('assistant professor-',),
#  ('marketing assistant-',),
#  ('budget/accounting analyst iii-',),
#  ('health coach iv-',),
#  ('account representative iv-',),
#  ('help desk operator-',),
#  ('director of sales-',),
#  ('quality control specialist-',),
#  ('associate professor-',),
#  ('research nurse-',),
#  ('account representative iii-',),
#  ('accountant i-',),
#  ('social worker-',),
#  ('assistant professor-',),
#  ('technical writer-',),
#  ('accountant ii-',),
#  ('executive secretary-',),
#  ('marketing manager-',),
#  ('administrative assistant iii-',),
#  ('business systems development analyst-',),
#  ('marketing manager-',),
#  ('civil engineer-',),
#  ('developer iv-',),
#  ('software engineer ii-',),
#  ('sales associate-',),
#  ('safety technician i-',),
#  ('teacher-',),
#  ('senior cost accountant-',),
#  ('financial advisor-',),
#  ('recruiting manager-',),
#  ('pharmacist-',),
#  ('database administrator i-',),
#  ('senior quality engineer-',),
#  ('senior cost accountant-',),
#  ('nurse practicioner-',),
#  ('research associate-',),
#  ('graphic designer-',),
#  ('vp product management-',),
#  ('environmental tech-',),
#  ('statistician i-',),
#  ('desktop support technician-',),
#  ('recruiting manager-',),
#  ('engineer i-',),
#  ('chemical engineer-',),
#  ('mechanical systems engineer-',),
#  ('senior sales associate-',),
#  ('senior editor-',),
#  ('programmer analyst iv-',),
#  ('professor-',),
#  ('editor-',),
#  ('financial advisor-',),
#  ('account representative iii-',),
#  ('director of sales-',),
#  ('registered nurse-',),
#  ('technical writer-',),
#  ('quality control specialist-',),
#  ('librarian-',),
#  ('employees accountant i-',),
#  ('help desk technician-',),
#  ('senior sales associate-',),
#  ('product engineer-',),
#  ('vp marketing-',),
#  ('food chemist-',),
#  ('pharmacist-',),
#  ('human resources assistant iii-',),
#  ('operator-',),
#  ('systems administrator iii-',),
#  ('teacher-',),
#  ('registered nurse-',),
#  ('software engineer i-',),
#  ('systems administrator i-',),
#  ('product engineer-',),
#  ('recruiter-',),
#  ('senior cost accountant-',),
#  ('gis technical architect-',),
#  ('community outreach specialist-',),
#  ('nuclear power engineer-',),
#  ('gis technical architect-',),
#  ('budget/accounting analyst ii-',),
#  ('biostatistician iii-',),
#  ('structural analysis engineer-',),
#  ('project manager-',),
#  ('help desk operator-',),
#  ('design engineer-',),
#  ('health coach iv-',),
#  ('structural engineer-',),
#  ('structural analysis engineer-',),
#  ('paralegal-',),
#  ('tax accountant-',),
#  ('research nurse-',),
#  ('executive secretary-',),
#  ('accountant i-',),
#  ('occupational therapist-',),
#  ('environmental specialist-',),
#  ('accounting assistant i-',),
#  ('database administrator i-',),
#  ('analog circuit design manager-',),
#  ('teacher-',),
#  ('structural engineer-',),
#  ('geological engineer-',),
#  ('associate professor-',),
#  ('senior financial analyst-',),
#  ('civil engineer-',),
#  ('accountant i-',),
#  ('assistant media planner-',),
#  ('database administrator ii-',),
#  ('vp quality control-',),
#  ('librarian-',),
#  ('software consultant-',),
#  ('teacher-',),
#  ('research nurse-',),
#  ('project manager-',),
#  ('systems administrator iv-',),
#  ('geological engineer-',),
#  ('nuclear power engineer-',),
#  ('vp product management-',),
#  ('gis technical architect-',),
#  ('budget/accounting analyst iii-',),
#  ('account coordinator-',),
#  ('vp quality control-',),
#  ('registered nurse-',),
#  ('social worker-',),
#  ('cost accountant-',),
#  ('assistant manager-',),
#  ('senior sales associate-',),
#  ('account representative iv-',),
#  ('programmer analyst iv-',),
#  ('compensation analyst-',),
#  ('civil engineer-',),
#  ('safety technician i-',),
#  ('business systems development analyst-',),
#  ('vp marketing-',),
#  ('data coordiator-',),
#  ('chemical engineer-',),
#  ('human resources assistant iv-',),
#  ('technical writer-',),
#  ('professor-',),
#  ('sales representative-',),
#  ('geological engineer-',),
#  ('payment adjustment coordinator-',),
#  ('product engineer-',),
#  ('geological engineer-',),
#  ('analog circuit design manager-',),
#  ('geologist iii-',),
#  ('senior quality engineer-',),
#  ('budget/accounting analyst iii-',),
#  ('environmental tech-',),
#  ('office assistant iii-',),
#  ('systems administrator iv-',),
#  ('desktop support technician-',),
#  ('engineer i-',),
#  ('general manager-',),
#  ('chemical engineer-',),
#  ('graphic designer-',),
#  ('payment adjustment coordinator-',),
#  ('business systems development analyst-',),
#  ('systems administrator i-',),
#  ('editor-',),
#  ('graphic designer-',),
#  ('electrical engineer-',),
#  ('help desk operator-',),
#  ('environmental specialist-',),
#  ('research assistant iii-',),
#  ('database administrator i-',),
#  ('account executive-',),
#  ('recruiting manager-',),
#  ('social worker-',),
#  ('social worker-',),
#  ('research nurse-',),
#  ('assistant media planner-',),
#  ('sales representative-',),
#  ...]

# %%
engine.execute("select concat_ws(' - ', job_title, last_name, email) from employees limit 5;").fetchall()
# Out:
# [('structural engineer - kelley - rkelley0@soundcloud.com',),
#  ('marketing assistant - alexander - kalexanderl@marketwatch.com',),
#  ('recruiting manager - carr - fcarr2@woothemes.com',),
#  ('electrical engineer - nguyen - mnguyen18@biblegateway.com',),
#  ('senior editor - armstrong - parmstrong1d@hc360.com',)]

# %%
# engine.execute("""select job_title, 
#                         (job_title like %%assistant%%) is_assistant
#                         from employees
#                         where job_title like '%%assistant%%';""").fetchall()

# %%
engine.execute(
    """
    select distinct(job_title)
    from employees;
    """
).fetchall()
# Out:
# [('biostatistician ii',),
#  ('software consultant',),
#  ('account representative iv',),
#  ('database administrator i',),
#  ('administrative assistant i',),
#  ('programmer analyst ii',),
#  ('biostatistician i',),
#  ('quality control specialist',),
#  ('research assistant iii',),
#  ('analyst programmer',),
#  ('help desk technician',),
#  ('chief design engineer',),
#  ('statistician iv',),
#  ('vp accounting',),
#  ('food chemist',),
#  ('programmer analyst iv',),
#  ('media manager ii',),
#  ('editor',),
#  ('programmer iv',),
#  ('human resources assistant ii',),
#  ('electrical engineer',),
#  ('developer iv',),
#  ('nuclear power engineer',),
#  ('senior financial analyst',),
#  ('developer iii',),
#  ('budget/accounting analyst iii',),
#  ('recruiter',),
#  ('account representative i',),
#  ('automation specialist iv',),
#  ('health coach iv',),
#  ('administrative assistant ii',),
#  ('environmental tech',),
#  ('product engineer',),
#  ('administrative assistant iii',),
#  ('employees accountant i',),
#  ('accountant iii',),
#  ('media manager i',),
#  ('payment adjustment coordinator',),
#  ('programmer analyst i',),
#  ('human resources assistant iv',),
#  ('biostatistician iv',),
#  ('developer ii',),
#  ('software engineer iv',),
#  ('health coach iii',),
#  ('human resources assistant i',),
#  ('software test engineer iii',),
#  ('sales representative',),
#  ('pharmacist',),
#  ('technical writer',),
#  ('business systems development analyst',),
#  ('accountant ii',),
#  ('environmental specialist',),
#  ('programmer i',),
#  ('geologist iii',),
#  ('civil engineer',),
#  ('help desk operator',),
#  ('associate professor',),
#  ('accounting assistant ii',),
#  ('employees scientist',),
#  ('clinical specialist',),
#  ('web designer i',),
#  ('financial advisor',),
#  ('safety technician iv',),
#  ('desktop support technician',),
#  ('systems administrator i',),
#  ('dental hygienist',),
#  ('vp quality control',),
#  ('chemical engineer',),
#  ('information systems manager',),
#  ('geologist ii',),
#  ('assistant professor',),
#  ('computer systems analyst iii',),
#  ('account executive',),
#  ('software engineer iii',),
#  ('junior executive',),
#  ('research assistant i',),
#  ('teacher',),
#  ('registered nurse',),
#  ('actuary',),
#  ('programmer iii',),
#  ('accounting assistant iv',),
#  ('accountant iv',),
#  ('librarian',),
#  ('structural engineer',),
#  ('nurse practicioner',),
#  ('compensation analyst',),
#  ('gis technical architect',),
#  ('recruiting manager',),
#  ('analog circuit design manager',),
#  ('cost accountant',),
#  ('statistician i',),
#  ('assistant manager',),
#  ('office assistant iii',),
#  ('web developer iv',),
#  ('geologist i',),
#  ('human resources manager',),
#  ('community outreach specialist',),
#  ('research assistant iv',),
#  ('research associate',),
#  ('engineer iii',),
#  ('financial analyst',),
#  ('design engineer',),
#  ('engineer ii',),
#  ('senior developer',),
#  ('geologist iv',),
#  ('account coordinator',),
#  ('speech pathologist',),
#  ('engineer iv',),
#  ('structural analysis engineer',),
#  ('quality engineer',),
#  ('marketing manager',),
#  ('geological engineer',),
#  ('social worker',),
#  ('computer systems analyst iv',),
#  ('systems administrator iv',),
#  ('software test engineer iv',),
#  ('software test engineer i',),
#  ('occupational therapist',),
#  ('professor',),
#  ('biostatistician iii',),
#  ('account representative iii',),
#  ('account representative ii',),
#  ('computer systems analyst i',),
#  ('statistician ii',),
#  ('safety technician i',),
#  ('office assistant iv',),
#  ('general manager',),
#  ('software engineer i',),
#  ('senior sales associate',),
#  ('sales associate',),
#  ('automation specialist i',),
#  ('budget/accounting analyst ii',),
#  ('senior editor',),
#  ('web designer ii',),
#  ('health coach i',),
#  ('employees accountant iii',),
#  ('nurse',),
#  ('executive secretary',),
#  ('administrative assistant iv',),
#  ('vp product management',),
#  ('database administrator iv',),
#  ('web designer iii',),
#  ('research assistant ii',),
#  ('accounting assistant i',),
#  ('database administrator iii',),
#  ('assistant media planner',),
#  ('vp marketing',),
#  ('research nurse',),
#  ('web developer i',),
#  ('computer systems analyst ii',),
#  ('director of sales',),
#  ('human resources assistant iii',),
#  ('web developer iii',),
#  ('data coordiator',),
#  ('senior quality engineer',),
#  ('physical therapy assistant',),
#  ('media manager iii',),
#  ('office assistant i',),
#  ('programmer analyst iii',),
#  ('tax accountant',),
#  ('web developer ii',),
#  ('graphic designer',),
#  ('employees accountant ii',),
#  ('operator',),
#  ('paralegal',),
#  ('internal auditor',),
#  ('health coach ii',),
#  ('marketing assistant',),
#  ('software test engineer ii',),
#  ('legal assistant',),
#  ('administrative officer',),
#  ('systems administrator iii',),
#  ('accounting assistant iii',),
#  ('office assistant ii',),
#  ('programmer ii',),
#  ('accountant i',),
#  ('systems administrator ii',),
#  ('mechanical systems engineer',),
#  ('employees accountant iv',),
#  ('project manager',),
#  ('developer i',),
#  ('engineer i',),
#  ('senior cost accountant',),
#  ('vp sales',),
#  ('database administrator ii',),
#  ('software engineer ii',)]

# %%
engine.execute(
    """
    select distinct(job_title)
    from employees
    where job_title like 'vp%%'
    or job_title like 'web%%';
    """
).fetchall()
# Out:
# [('web developer ii',),
#  ('vp marketing',),
#  ('vp quality control',),
#  ('web developer iv',),
#  ('web developer i',),
#  ('web designer ii',),
#  ('web designer i',),
#  ('web developer iii',),
#  ('vp accounting',),
#  ('vp product management',),
#  ('vp sales',),
#  ('web designer iii',)]

# %%
engine.execute(
    """
    select distinct(job_title)
    from employees
    where job_title similar to '(vp%%|web%%)'; -- don't add any spaces
    """
).fetchall()
# Out:
# [('web developer ii',),
#  ('vp marketing',),
#  ('vp quality control',),
#  ('web developer iv',),
#  ('web developer i',),
#  ('web designer ii',),
#  ('web designer i',),
#  ('web developer iii',),
#  ('vp accounting',),
#  ('vp product management',),
#  ('vp sales',),
#  ('web designer iii',)]

# %% [markdown]
# reformat numeric data
